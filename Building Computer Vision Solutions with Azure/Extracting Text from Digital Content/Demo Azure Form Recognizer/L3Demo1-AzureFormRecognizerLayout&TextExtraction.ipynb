# %% [markdown]
# ### Importing Azure Form Recognizer python modules

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import FormRecognizerClient

# %%
AZURE_FORM_RECOGNIZER_ENDPOINT = "https://--------------------------.cognitiveservices.azure.com/"
AZURE_FORM_RECOGNIZER_KEY = "------------------------------"

# %%
endpoint = AZURE_FORM_RECOGNIZER_ENDPOINT
key = AZURE_FORM_RECOGNIZER_KEY

# %%
form_recognizer_client = FormRecognizerClient(endpoint=endpoint, credential=AzureKeyCredential(key))

# %% [markdown]
# ### Input Resource and Extracting Results

# %%
content_url = "https://raw.githubusercontent.com/udacity/cd0461-building-computer-vision-solutions-with-azure-exercises/main/resources/invoice-2.png"

# %%
invoices_from_url = form_recognizer_client.begin_recognize_content_from_url(content_url)

# %%
invoices_from_url

# %%
result_data = invoices_from_url.result()

# %%
result_data
# Out:
# [FormPage(page_number=1, text_angle=-0.1591, width=1486.0, height=1740.0, unit=pixel, tables=[FormTable(page_number=1, cells=[FormTableCell(text=DESCRIPTION, row_index=0, column_index=0, row_span=1, column_span=1, bounding_box=[Point(x=61.0, y=839.0), Point(x=634.0, y=841.0), Point(x=634.0, y=909.0), Point(x=61.0, y=907.0)], confidence=1.0, is_header=True, is_footer=False, page_number=1, field_elements=[FormWord(text=DESCRIPTION, bounding_box=[Point(x=70.0, y=867.0), Point(x=203.0, y=866.0), Point(x=203.0, y=886.0), Point(x=71.0, y=887.0)], confidence=0.991, page_number=1, kind=word)]), FormTableCell(text=RATE, row_index=0, column_index=1, row_span=1, column_span=1, bounding_box=[Point(x=634.0, y=841.0), Point(x=1162.0, y=839.0), Point(x=1163.0, y=909.0), Point(x=634.0, y=909.0)], confidence=1.0, is_header=True, is_footer=False, page_number=1, field_elements=[FormWord(text=RATE, bounding_box=[Point(x=1073.0, y=866.0), Point(x=1123.0, y=866.0), Point(x=1123.0, y=885.0), Point(x=1073.0, y=885.0)], confidence=0.9]

# %% [markdown]
# ### Processing Results

# %%
len(result_data)
# Out:
# 1

# %%
content = result_data[0]

# %%
content
# Out:
# FormPage(page_number=1, text_angle=-0.1591, width=1486.0, height=1740.0, unit=pixel, tables=[FormTable(page_number=1, cells=[FormTableCell(text=DESCRIPTION, row_index=0, column_index=0, row_span=1, column_span=1, bounding_box=[Point(x=61.0, y=839.0), Point(x=634.0, y=841.0), Point(x=634.0, y=909.0), Point(x=61.0, y=907.0)], confidence=1.0, is_header=True, is_footer=False, page_number=1, field_elements=[FormWord(text=DESCRIPTION, bounding_box=[Point(x=70.0, y=867.0), Point(x=203.0, y=866.0), Point(x=203.0, y=886.0), Point(x=71.0, y=887.0)], confidence=0.991, page_number=1, kind=word)]), FormTableCell(text=RATE, row_index=0, column_index=1, row_span=1, column_span=1, bounding_box=[Point(x=634.0, y=841.0), Point(x=1162.0, y=839.0), Point(x=1163.0, y=909.0), Point(x=634.0, y=909.0)], confidence=1.0, is_header=True, is_footer=False, page_number=1, field_elements=[FormWord(text=RATE, bounding_box=[Point(x=1073.0, y=866.0), Point(x=1123.0, y=866.0), Point(x=1123.0, y=885.0), Point(x=1073.0, y=885.0)], confidence=0.9

# %%
content.to_dict()
# Out:
# {'page_number': 1,
#  'text_angle': -0.1591,
#  'width': 1486.0,
#  'height': 1740.0,
#  'unit': 'pixel',
#  'tables': [{'page_number': 1,
#    'row_count': 4,
#    'column_count': 4,
#    'cells': [{'text': 'DESCRIPTION',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 61.0, 'y': 839.0},
#       {'x': 634.0, 'y': 841.0},
#       {'x': 634.0, 'y': 909.0},
#       {'x': 61.0, 'y': 907.0}],
#      'field_elements': [{'text': 'DESCRIPTION',
#        'bounding_box': [{'x': 70.0, 'y': 867.0},
#         {'x': 203.0, 'y': 866.0},
#         {'x': 203.0, 'y': 886.0},
#         {'x': 71.0, 'y': 887.0}],
#        'confidence': 0.991,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'RATE',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 634.0, 'y': 841.0},
#       {'x': 1162.0, 'y': 839.0},
#       {'x': 1163.0, 'y': 909.0},
#       {'x': 634.0, 'y': 909.0}],
#      'field_elements': [{'text': 'RATE',
#        'bounding_box': [{'x': 1073.0, 'y': 866.0},
#         {'x': 1123.0, 'y': 866.0},
#         {'x': 1123.0, 'y': 885.0},
#         {'x': 1073.0, 'y': 885.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'QTY',
#      'row_index': 0,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1162.0, 'y': 839.0},
#       {'x': 1280.0, 'y': 839.0},
#       {'x': 1280.0, 'y': 909.0},
#       {'x': 1163.0, 'y': 909.0}],
#      'field_elements': [{'text': 'QTY',
#        'bounding_box': [{'x': 1196.0, 'y': 867.0},
#         {'x': 1237.0, 'y': 866.0},
#         {'x': 1238.0, 'y': 886.0},
#         {'x': 1197.0, 'y': 887.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'AMOUNT',
#      'row_index': 0,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 839.0},
#       {'x': 1421.0, 'y': 839.0},
#       {'x': 1421.0, 'y': 909.0},
#       {'x': 1280.0, 'y': 909.0}],
#      'field_elements': [{'text': 'AMOUNT',
#        'bounding_box': [{'x': 1320.0, 'y': 867.0},
#         {'x': 1409.0, 'y': 866.0},
#         {'x': 1409.0, 'y': 886.0},
#         {'x': 1320.0, 'y': 886.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Burger',
#      'row_index': 1,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 61.0, 'y': 907.0},
#       {'x': 634.0, 'y': 909.0},
#       {'x': 636.0, 'y': 978.0},
#       {'x': 60.0, 'y': 978.0}],
#      'field_elements': [{'text': 'Burger',
#        'bounding_box': [{'x': 70.0, 'y': 932.0},
#         {'x': 144.0, 'y': 933.0},
#         {'x': 144.0, 'y': 958.0},
#         {'x': 69.0, 'y': 957.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$6.99',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 634.0, 'y': 909.0},
#       {'x': 1163.0, 'y': 909.0},
#       {'x': 1163.0, 'y': 978.0},
#       {'x': 636.0, 'y': 978.0}],
#      'field_elements': [{'text': '$6.99',
#        'bounding_box': [{'x': 1062.0, 'y': 930.0},
#         {'x': 1124.0, 'y': 930.0},
#         {'x': 1124.0, 'y': 954.0},
#         {'x': 1062.0, 'y': 955.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1',
#      'row_index': 1,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1163.0, 'y': 909.0},
#       {'x': 1280.0, 'y': 909.0},
#       {'x': 1280.0, 'y': 978.0},
#       {'x': 1163.0, 'y': 978.0}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1228.0, 'y': 933.0},
#         {'x': 1239.0, 'y': 935.0},
#         {'x': 1236.0, 'y': 952.0},
#         {'x': 1226.0, 'y': 951.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$6.99',
#      'row_index': 1,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 909.0},
#       {'x': 1421.0, 'y': 909.0},
#       {'x': 1421.0, 'y': 978.0},
#       {'x': 1280.0, 'y': 978.0}],
#      'field_elements': [{'text': '$6.99',
#        'bounding_box': [{'x': 1348.0, 'y': 931.0},
#         {'x': 1410.0, 'y': 931.0},
#         {'x': 1410.0, 'y': 954.0},
#         {'x': 1348.0, 'y': 955.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Drink',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 60.0, 'y': 978.0},
#       {'x': 636.0, 'y': 978.0},
#       {'x': 636.0, 'y': 1049.0},
#       {'x': 60.0, 'y': 1049.0}],
#      'field_elements': [{'text': 'Drink',
#        'bounding_box': [{'x': 70.0, 'y': 1001.0},
#         {'x': 127.0, 'y': 1001.0},
#         {'x': 127.0, 'y': 1024.0},
#         {'x': 70.0, 'y': 1023.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$2.99',
#      'row_index': 2,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 636.0, 'y': 978.0},
#       {'x': 1163.0, 'y': 978.0},
#       {'x': 1163.0, 'y': 1049.0},
#       {'x': 636.0, 'y': 1049.0}],
#      'field_elements': [{'text': '$2.99',
#        'bounding_box': [{'x': 1062.0, 'y': 1001.0},
#         {'x': 1123.0, 'y': 1000.0},
#         {'x': 1124.0, 'y': 1023.0},
#         {'x': 1062.0, 'y': 1024.0}],
#        'confidence': 0.986,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1',
#      'row_index': 2,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1163.0, 'y': 978.0},
#       {'x': 1280.0, 'y': 978.0},
#       {'x': 1280.0, 'y': 1049.0},
#       {'x': 1163.0, 'y': 1049.0}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1226.0, 'y': 1004.0},
#         {'x': 1238.0, 'y': 1004.0},
#         {'x': 1237.0, 'y': 1024.0},
#         {'x': 1226.0, 'y': 1024.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$2.99',
#      'row_index': 2,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 978.0},
#       {'x': 1421.0, 'y': 978.0},
#       {'x': 1421.0, 'y': 1049.0},
#       {'x': 1280.0, 'y': 1049.0}],
#      'field_elements': [{'text': '$2.99',
#        'bounding_box': [{'x': 1347.0, 'y': 1001.0},
#         {'x': 1409.0, 'y': 1000.0},
#         {'x': 1409.0, 'y': 1023.0},
#         {'x': 1348.0, 'y': 1025.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Icecreame',
#      'row_index': 3,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 60.0, 'y': 1049.0},
#       {'x': 636.0, 'y': 1049.0},
#       {'x': 636.0, 'y': 1118.0},
#       {'x': 60.0, 'y': 1118.0}],
#      'field_elements': [{'text': 'Icecreame',
#        'bounding_box': [{'x': 71.0, 'y': 1073.0},
#         {'x': 185.0, 'y': 1074.0},
#         {'x': 186.0, 'y': 1095.0},
#         {'x': 71.0, 'y': 1094.0}],
#        'confidence': 0.748,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$4.99',
#      'row_index': 3,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 636.0, 'y': 1049.0},
#       {'x': 1163.0, 'y': 1049.0},
#       {'x': 1163.0, 'y': 1118.0},
#       {'x': 636.0, 'y': 1118.0}],
#      'field_elements': [{'text': '$4.99',
#        'bounding_box': [{'x': 1062.0, 'y': 1071.0},
#         {'x': 1125.0, 'y': 1070.0},
#         {'x': 1126.0, 'y': 1094.0},
#         {'x': 1062.0, 'y': 1095.0}],
#        'confidence': 0.981,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1',
#      'row_index': 3,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1163.0, 'y': 1049.0},
#       {'x': 1280.0, 'y': 1049.0},
#       {'x': 1280.0, 'y': 1118.0},
#       {'x': 1163.0, 'y': 1118.0}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1228.0, 'y': 1073.0},
#         {'x': 1238.0, 'y': 1074.0},
#         {'x': 1236.0, 'y': 1092.0},
#         {'x': 1226.0, 'y': 1091.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$4.99',
#      'row_index': 3,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 1049.0},
#       {'x': 1421.0, 'y': 1049.0},
#       {'x': 1421.0, 'y': 1118.0},
#       {'x': 1280.0, 'y': 1118.0}],
#      'field_elements': [{'text': '$4.99',
#        'bounding_box': [{'x': 1347.0, 'y': 1071.0},
#         {'x': 1410.0, 'y': 1071.0},
#         {'x': 1410.0, 'y': 1094.0},
#         {'x': 1347.0, 'y': 1094.0}],
#        'confidence': 0.991,
#        'page_number': 1,
#        'kind': 'word'}]}],
#    'bounding_box': [{'x': 66.0, 'y': 836.0},
#     {'x': 1419.0, 'y': 836.0},
#     {'x': 1419.0, 'y': 1120.0},
#     {'x': 66.0, 'y': 1120.0}]}],
#  'lines': [{'text': 'INVOICE',
#    'bounding_box': [{'x': 1328.0, 'y': 34.0},
#     {'x': 1414.0, 'y': 33.0},
#     {'x': 1414.0, 'y': 53.0},
#     {'x': 1328.0, 'y': 54.0}],
#    'words': [{'text': 'INVOICE',
#      'bounding_box': [{'x': 1329.0, 'y': 34.0},
#       {'x': 1409.0, 'y': 34.0},
#       {'x': 1409.0, 'y': 54.0},
#       {'x': 1328.0, 'y': 54.0}],
#      'confidence': 0.995,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Champion Store',
#    'bounding_box': [{'x': 377.0, 'y': 88.0},
#     {'x': 641.0, 'y': 88.0},
#     {'x': 641.0, 'y': 122.0},
#     {'x': 377.0, 'y': 122.0}],
#    'words': [{'text': 'Champion',
#      'bounding_box': [{'x': 378.0, 'y': 88.0},
#       {'x': 540.0, 'y': 89.0},
#       {'x': 539.0, 'y': 123.0},
#       {'x': 378.0, 'y': 122.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Store',
#      'bounding_box': [{'x': 550.0, 'y': 89.0},
#       {'x': 638.0, 'y': 90.0},
#       {'x': 638.0, 'y': 121.0},
#       {'x': 549.0, 'y': 123.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'K34545455',
#    'bounding_box': [{'x': 1282.0, 'y': 71.0},
#     {'x': 1412.0, 'y': 71.0},
#     {'x': 1412.0, 'y': 94.0},
#     {'x': 1282.0, 'y': 94.0}],
#    'words': [{'text': 'K34545455',
#      'bounding_box': [{'x': 1282.0, 'y': 72.0},
#       {'x': 1410.0, 'y': 72.0},
#       {'x': 1410.0, 'y': 95.0},
#       {'x': 1282.0, 'y': 94.0}],
#      'confidence': 0.986,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Business Number 22323232-24',
#    'bounding_box': [{'x': 378.0, 'y': 145.0},
#     {'x': 738.0, 'y': 144.0},
#     {'x': 738.0, 'y': 168.0},
#     {'x': 378.0, 'y': 169.0}],
#    'words': [{'text': 'Business',
#      'bounding_box': [{'x': 378.0, 'y': 146.0},
#       {'x': 479.0, 'y': 146.0},
#       {'x': 480.0, 'y': 170.0},
#       {'x': 378.0, 'y': 169.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Number',
#      'bounding_box': [{'x': 484.0, 'y': 146.0},
#       {'x': 581.0, 'y': 145.0},
#       {'x': 581.0, 'y': 170.0},
#       {'x': 484.0, 'y': 170.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '22323232-24',
#      'bounding_box': [{'x': 586.0, 'y': 145.0},
#       {'x': 735.0, 'y': 145.0},
#       {'x': 735.0, 'y': 169.0},
#       {'x': 586.0, 'y': 170.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DATE',
#    'bounding_box': [{'x': 1358.0, 'y': 130.0},
#     {'x': 1413.0, 'y': 130.0},
#     {'x': 1412.0, 'y': 149.0},
#     {'x': 1358.0, 'y': 150.0}],
#    'words': [{'text': 'DATE',
#      'bounding_box': [{'x': 1358.0, 'y': 130.0},
#       {'x': 1409.0, 'y': 130.0},
#       {'x': 1409.0, 'y': 150.0},
#       {'x': 1358.0, 'y': 150.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '65 Longhorn Ave',
#    'bounding_box': [{'x': 378.0, 'y': 184.0},
#     {'x': 570.0, 'y': 185.0},
#     {'x': 570.0, 'y': 211.0},
#     {'x': 378.0, 'y': 211.0}],
#    'words': [{'text': '65',
#      'bounding_box': [{'x': 379.0, 'y': 185.0},
#       {'x': 404.0, 'y': 185.0},
#       {'x': 405.0, 'y': 211.0},
#       {'x': 380.0, 'y': 211.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Longhorn',
#      'bounding_box': [{'x': 409.0, 'y': 185.0},
#       {'x': 518.0, 'y': 185.0},
#       {'x': 518.0, 'y': 212.0},
#       {'x': 410.0, 'y': 211.0}],
#      'confidence': 0.995,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Ave',
#      'bounding_box': [{'x': 523.0, 'y': 185.0},
#       {'x': 568.0, 'y': 185.0},
#       {'x': 569.0, 'y': 211.0},
#       {'x': 523.0, 'y': 212.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Aug 2, 2021',
#    'bounding_box': [{'x': 1278.0, 'y': 168.0},
#     {'x': 1412.0, 'y': 166.0},
#     {'x': 1412.0, 'y': 192.0},
#     {'x': 1279.0, 'y': 194.0}],
#    'words': [{'text': 'Aug',
#      'bounding_box': [{'x': 1279.0, 'y': 169.0},
#       {'x': 1322.0, 'y': 168.0},
#       {'x': 1322.0, 'y': 194.0},
#       {'x': 1279.0, 'y': 194.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '2,',
#      'bounding_box': [{'x': 1327.0, 'y': 168.0},
#       {'x': 1348.0, 'y': 168.0},
#       {'x': 1348.0, 'y': 194.0},
#       {'x': 1327.0, 'y': 194.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '2021',
#      'bounding_box': [{'x': 1353.0, 'y': 168.0},
#       {'x': 1411.0, 'y': 167.0},
#       {'x': 1411.0, 'y': 193.0},
#       {'x': 1353.0, 'y': 194.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'San Mateo',
#    'bounding_box': [{'x': 378.0, 'y': 225.0},
#     {'x': 499.0, 'y': 225.0},
#     {'x': 499.0, 'y': 248.0},
#     {'x': 378.0, 'y': 248.0}],
#    'words': [{'text': 'San',
#      'bounding_box': [{'x': 380.0, 'y': 226.0},
#       {'x': 418.0, 'y': 226.0},
#       {'x': 418.0, 'y': 249.0},
#       {'x': 380.0, 'y': 249.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Mateo',
#      'bounding_box': [{'x': 423.0, 'y': 226.0},
#       {'x': 497.0, 'y': 226.0},
#       {'x': 496.0, 'y': 249.0},
#       {'x': 423.0, 'y': 249.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DUE',
#    'bounding_box': [{'x': 1371.0, 'y': 226.0},
#     {'x': 1413.0, 'y': 226.0},
#     {'x': 1413.0, 'y': 245.0},
#     {'x': 1371.0, 'y': 245.0}],
#    'words': [{'text': 'DUE',
#      'bounding_box': [{'x': 1371.0, 'y': 226.0},
#       {'x': 1410.0, 'y': 226.0},
#       {'x': 1410.0, 'y': 245.0},
#       {'x': 1371.0, 'y': 245.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '94401',
#    'bounding_box': [{'x': 378.0, 'y': 267.0},
#     {'x': 449.0, 'y': 266.0},
#     {'x': 449.0, 'y': 289.0},
#     {'x': 378.0, 'y': 290.0}],
#    'words': [{'text': '94401',
#      'bounding_box': [{'x': 379.0, 'y': 268.0},
#       {'x': 449.0, 'y': 267.0},
#       {'x': 449.0, 'y': 290.0},
#       {'x': 379.0, 'y': 290.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'On Receipt',
#    'bounding_box': [{'x': 1291.0, 'y': 261.0},
#     {'x': 1415.0, 'y': 262.0},
#     {'x': 1415.0, 'y': 291.0},
#     {'x': 1291.0, 'y': 290.0}],
#    'words': [{'text': 'On',
#      'bounding_box': [{'x': 1292.0, 'y': 262.0},
#       {'x': 1317.0, 'y': 262.0},
#       {'x': 1318.0, 'y': 291.0},
#       {'x': 1292.0, 'y': 291.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Receipt',
#      'bounding_box': [{'x': 1323.0, 'y': 262.0},
#       {'x': 1414.0, 'y': 262.0},
#       {'x': 1415.0, 'y': 292.0},
#       {'x': 1324.0, 'y': 291.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '4084352313',
#    'bounding_box': [{'x': 377.0, 'y': 304.0},
#     {'x': 522.0, 'y': 304.0},
#     {'x': 522.0, 'y': 332.0},
#     {'x': 377.0, 'y': 332.0}],
#    'words': [{'text': '4084352313',
#      'bounding_box': [{'x': 378.0, 'y': 305.0},
#       {'x': 522.0, 'y': 305.0},
#       {'x': 522.0, 'y': 333.0},
#       {'x': 378.0, 'y': 333.0}],
#      'confidence': 0.986,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'BALANCE DUE',
#    'bounding_box': [{'x': 1268.0, 'y': 322.0},
#     {'x': 1413.0, 'y': 322.0},
#     {'x': 1414.0, 'y': 341.0},
#     {'x': 1268.0, 'y': 342.0}],
#    'words': [{'text': 'BALANCE',
#      'bounding_box': [{'x': 1269.0, 'y': 323.0},
#       {'x': 1364.0, 'y': 322.0},
#       {'x': 1363.0, 'y': 342.0},
#       {'x': 1269.0, 'y': 343.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'DUE',
#      'bounding_box': [{'x': 1368.0, 'y': 322.0},
#       {'x': 1409.0, 'y': 322.0},
#       {'x': 1409.0, 'y': 342.0},
#       {'x': 1368.0, 'y': 342.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'champstore@gmail.com',
#    'bounding_box': [{'x': 379.0, 'y': 348.0},
#     {'x': 655.0, 'y': 347.0},
#     {'x': 655.0, 'y': 373.0},
#     {'x': 379.0, 'y': 374.0}],
#    'words': [{'text': 'champstore@gmail.com',
#      'bounding_box': [{'x': 379.0, 'y': 349.0},
#       {'x': 644.0, 'y': 349.0},
#       {'x': 643.0, 'y': 373.0},
#       {'x': 380.0, 'y': 373.0}],
#      'confidence': 0.938,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'USD $16.32',
#    'bounding_box': [{'x': 1279.0, 'y': 359.0},
#     {'x': 1413.0, 'y': 359.0},
#     {'x': 1413.0, 'y': 382.0},
#     {'x': 1279.0, 'y': 382.0}],
#    'words': [{'text': 'USD',
#      'bounding_box': [{'x': 1279.0, 'y': 360.0},
#       {'x': 1322.0, 'y': 359.0},
#       {'x': 1322.0, 'y': 383.0},
#       {'x': 1280.0, 'y': 383.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '$16.32',
#      'bounding_box': [{'x': 1331.0, 'y': 359.0},
#       {'x': 1410.0, 'y': 359.0},
#       {'x': 1410.0, 'y': 383.0},
#       {'x': 1332.0, 'y': 383.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'BILL TO',
#    'bounding_box': [{'x': 70.0, 'y': 496.0},
#     {'x': 147.0, 'y': 496.0},
#     {'x': 147.0, 'y': 515.0},
#     {'x': 70.0, 'y': 516.0}],
#    'words': [{'text': 'BILL',
#      'bounding_box': [{'x': 70.0, 'y': 497.0},
#       {'x': 111.0, 'y': 496.0},
#       {'x': 111.0, 'y': 516.0},
#       {'x': 70.0, 'y': 517.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'TO',
#      'bounding_box': [{'x': 118.0, 'y': 496.0},
#       {'x': 141.0, 'y': 496.0},
#       {'x': 141.0, 'y': 516.0},
#       {'x': 117.0, 'y': 516.0}],
#      'confidence': 0.998,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'James Starter',
#    'bounding_box': [{'x': 69.0, 'y': 543.0},
#     {'x': 277.0, 'y': 543.0},
#     {'x': 277.0, 'y': 571.0},
#     {'x': 69.0, 'y': 570.0}],
#    'words': [{'text': 'James',
#      'bounding_box': [{'x': 70.0, 'y': 543.0},
#       {'x': 165.0, 'y': 543.0},
#       {'x': 165.0, 'y': 571.0},
#       {'x': 71.0, 'y': 571.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Starter',
#      'bounding_box': [{'x': 173.0, 'y': 543.0},
#       {'x': 276.0, 'y': 545.0},
#       {'x': 276.0, 'y': 571.0},
#       {'x': 173.0, 'y': 571.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '3212 Leghorn Rd',
#    'bounding_box': [{'x': 69.0, 'y': 597.0},
#     {'x': 264.0, 'y': 597.0},
#     {'x': 264.0, 'y': 623.0},
#     {'x': 69.0, 'y': 623.0}],
#    'words': [{'text': '3212',
#      'bounding_box': [{'x': 70.0, 'y': 597.0},
#       {'x': 124.0, 'y': 597.0},
#       {'x': 124.0, 'y': 624.0},
#       {'x': 70.0, 'y': 622.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Leghorn',
#      'bounding_box': [{'x': 129.0, 'y': 597.0},
#       {'x': 223.0, 'y': 597.0},
#       {'x': 223.0, 'y': 624.0},
#       {'x': 129.0, 'y': 624.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Rd',
#      'bounding_box': [{'x': 228.0, 'y': 597.0},
#       {'x': 260.0, 'y': 597.0},
#       {'x': 259.0, 'y': 623.0},
#       {'x': 227.0, 'y': 624.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Mountain View',
#    'bounding_box': [{'x': 71.0, 'y': 638.0},
#     {'x': 239.0, 'y': 637.0},
#     {'x': 239.0, 'y': 660.0},
#     {'x': 71.0, 'y': 661.0}],
#    'words': [{'text': 'Mountain',
#      'bounding_box': [{'x': 72.0, 'y': 638.0},
#       {'x': 174.0, 'y': 638.0},
#       {'x': 174.0, 'y': 661.0},
#       {'x': 72.0, 'y': 662.0}],
#      'confidence': 0.995,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'View',
#      'bounding_box': [{'x': 181.0, 'y': 638.0},
#       {'x': 231.0, 'y': 638.0},
#       {'x': 230.0, 'y': 661.0},
#       {'x': 180.0, 'y': 661.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '94040',
#    'bounding_box': [{'x': 69.0, 'y': 679.0},
#     {'x': 143.0, 'y': 679.0},
#     {'x': 143.0, 'y': 701.0},
#     {'x': 69.0, 'y': 702.0}],
#    'words': [{'text': '94040',
#      'bounding_box': [{'x': 71.0, 'y': 680.0},
#       {'x': 139.0, 'y': 679.0},
#       {'x': 139.0, 'y': 702.0},
#       {'x': 71.0, 'y': 702.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '4087031332',
#    'bounding_box': [{'x': 71.0, 'y': 719.0},
#     {'x': 214.0, 'y': 718.0},
#     {'x': 214.0, 'y': 742.0},
#     {'x': 71.0, 'y': 742.0}],
#    'words': [{'text': '4087031332',
#      'bounding_box': [{'x': 72.0, 'y': 720.0},
#       {'x': 210.0, 'y': 719.0},
#       {'x': 210.0, 'y': 743.0},
#       {'x': 72.0, 'y': 742.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'james_starter@email.com',
#    'bounding_box': [{'x': 66.0, 'y': 760.0},
#     {'x': 364.0, 'y': 759.0},
#     {'x': 364.0, 'y': 785.0},
#     {'x': 66.0, 'y': 785.0}],
#    'words': [{'text': 'james_starter@email.com',
#      'bounding_box': [{'x': 68.0, 'y': 761.0},
#       {'x': 355.0, 'y': 760.0},
#       {'x': 355.0, 'y': 785.0},
#       {'x': 69.0, 'y': 786.0}],
#      'confidence': 0.832,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DESCRIPTION',
#    'bounding_box': [{'x': 70.0, 'y': 866.0},
#     {'x': 209.0, 'y': 866.0},
#     {'x': 210.0, 'y': 885.0},
#     {'x': 70.0, 'y': 886.0}],
#    'words': [{'text': 'DESCRIPTION',
#      'bounding_box': [{'x': 70.0, 'y': 867.0},
#       {'x': 203.0, 'y': 866.0},
#       {'x': 203.0, 'y': 886.0},
#       {'x': 71.0, 'y': 887.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'RATE',
#    'bounding_box': [{'x': 1073.0, 'y': 867.0},
#     {'x': 1128.0, 'y': 866.0},
#     {'x': 1128.0, 'y': 885.0},
#     {'x': 1073.0, 'y': 885.0}],
#    'words': [{'text': 'RATE',
#      'bounding_box': [{'x': 1073.0, 'y': 866.0},
#       {'x': 1123.0, 'y': 866.0},
#       {'x': 1123.0, 'y': 885.0},
#       {'x': 1073.0, 'y': 885.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'QTY',
#    'bounding_box': [{'x': 1196.0, 'y': 867.0},
#     {'x': 1242.0, 'y': 866.0},
#     {'x': 1242.0, 'y': 885.0},
#     {'x': 1197.0, 'y': 887.0}],
#    'words': [{'text': 'QTY',
#      'bounding_box': [{'x': 1196.0, 'y': 867.0},
#       {'x': 1237.0, 'y': 866.0},
#       {'x': 1238.0, 'y': 886.0},
#       {'x': 1197.0, 'y': 887.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'AMOUNT',
#    'bounding_box': [{'x': 1319.0, 'y': 867.0},
#     {'x': 1412.0, 'y': 866.0},
#     {'x': 1412.0, 'y': 885.0},
#     {'x': 1319.0, 'y': 886.0}],
#    'words': [{'text': 'AMOUNT',
#      'bounding_box': [{'x': 1320.0, 'y': 867.0},
#       {'x': 1409.0, 'y': 866.0},
#       {'x': 1409.0, 'y': 886.0},
#       {'x': 1320.0, 'y': 886.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Burger',
#    'bounding_box': [{'x': 69.0, 'y': 931.0},
#     {'x': 145.0, 'y': 933.0},
#     {'x': 145.0, 'y': 958.0},
#     {'x': 69.0, 'y': 957.0}],
#    'words': [{'text': 'Burger',
#      'bounding_box': [{'x': 70.0, 'y': 932.0},
#       {'x': 144.0, 'y': 933.0},
#       {'x': 144.0, 'y': 958.0},
#       {'x': 69.0, 'y': 957.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$6.99',
#    'bounding_box': [{'x': 1061.0, 'y': 930.0},
#     {'x': 1125.0, 'y': 930.0},
#     {'x': 1125.0, 'y': 953.0},
#     {'x': 1062.0, 'y': 955.0}],
#    'words': [{'text': '$6.99',
#      'bounding_box': [{'x': 1062.0, 'y': 930.0},
#       {'x': 1124.0, 'y': 930.0},
#       {'x': 1124.0, 'y': 954.0},
#       {'x': 1062.0, 'y': 955.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '1',
#    'bounding_box': [{'x': 1225.0, 'y': 933.0},
#     {'x': 1241.0, 'y': 935.0},
#     {'x': 1240.0, 'y': 953.0},
#     {'x': 1224.0, 'y': 951.0}],
#    'words': [{'text': '1',
#      'bounding_box': [{'x': 1228.0, 'y': 933.0},
#       {'x': 1239.0, 'y': 935.0},
#       {'x': 1236.0, 'y': 952.0},
#       {'x': 1226.0, 'y': 951.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'handwriting', 'style_confidence': 0.357}},
#   {'text': '$6.99',
#    'bounding_box': [{'x': 1347.0, 'y': 931.0},
#     {'x': 1412.0, 'y': 931.0},
#     {'x': 1412.0, 'y': 953.0},
#     {'x': 1348.0, 'y': 955.0}],
#    'words': [{'text': '$6.99',
#      'bounding_box': [{'x': 1348.0, 'y': 931.0},
#       {'x': 1410.0, 'y': 931.0},
#       {'x': 1410.0, 'y': 954.0},
#       {'x': 1348.0, 'y': 955.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Drink',
#    'bounding_box': [{'x': 70.0, 'y': 1001.0},
#     {'x': 129.0, 'y': 1001.0},
#     {'x': 128.0, 'y': 1024.0},
#     {'x': 70.0, 'y': 1023.0}],
#    'words': [{'text': 'Drink',
#      'bounding_box': [{'x': 70.0, 'y': 1001.0},
#       {'x': 127.0, 'y': 1001.0},
#       {'x': 127.0, 'y': 1024.0},
#       {'x': 70.0, 'y': 1023.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$2.99',
#    'bounding_box': [{'x': 1061.0, 'y': 1001.0},
#     {'x': 1125.0, 'y': 1000.0},
#     {'x': 1125.0, 'y': 1022.0},
#     {'x': 1062.0, 'y': 1024.0}],
#    'words': [{'text': '$2.99',
#      'bounding_box': [{'x': 1062.0, 'y': 1001.0},
#       {'x': 1123.0, 'y': 1000.0},
#       {'x': 1124.0, 'y': 1023.0},
#       {'x': 1062.0, 'y': 1024.0}],
#      'confidence': 0.986,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '1',
#    'bounding_box': [{'x': 1224.0, 'y': 1004.0},
#     {'x': 1241.0, 'y': 1004.0},
#     {'x': 1241.0, 'y': 1024.0},
#     {'x': 1224.0, 'y': 1023.0}],
#    'words': [{'text': '1',
#      'bounding_box': [{'x': 1226.0, 'y': 1004.0},
#       {'x': 1238.0, 'y': 1004.0},
#       {'x': 1237.0, 'y': 1024.0},
#       {'x': 1226.0, 'y': 1024.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$2.99',
#    'bounding_box': [{'x': 1347.0, 'y': 1001.0},
#     {'x': 1410.0, 'y': 1000.0},
#     {'x': 1410.0, 'y': 1022.0},
#     {'x': 1347.0, 'y': 1025.0}],
#    'words': [{'text': '$2.99',
#      'bounding_box': [{'x': 1347.0, 'y': 1001.0},
#       {'x': 1409.0, 'y': 1000.0},
#       {'x': 1409.0, 'y': 1023.0},
#       {'x': 1348.0, 'y': 1025.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Icecreame',
#    'bounding_box': [{'x': 70.0, 'y': 1073.0},
#     {'x': 190.0, 'y': 1073.0},
#     {'x': 189.0, 'y': 1094.0},
#     {'x': 70.0, 'y': 1093.0}],
#    'words': [{'text': 'Icecreame',
#      'bounding_box': [{'x': 71.0, 'y': 1073.0},
#       {'x': 185.0, 'y': 1074.0},
#       {'x': 186.0, 'y': 1095.0},
#       {'x': 71.0, 'y': 1094.0}],
#      'confidence': 0.748,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$4.99',
#    'bounding_box': [{'x': 1061.0, 'y': 1071.0},
#     {'x': 1127.0, 'y': 1070.0},
#     {'x': 1127.0, 'y': 1093.0},
#     {'x': 1062.0, 'y': 1095.0}],
#    'words': [{'text': '$4.99',
#      'bounding_box': [{'x': 1062.0, 'y': 1071.0},
#       {'x': 1125.0, 'y': 1070.0},
#       {'x': 1126.0, 'y': 1094.0},
#       {'x': 1062.0, 'y': 1095.0}],
#      'confidence': 0.981,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '1',
#    'bounding_box': [{'x': 1226.0, 'y': 1073.0},
#     {'x': 1241.0, 'y': 1075.0},
#     {'x': 1240.0, 'y': 1093.0},
#     {'x': 1225.0, 'y': 1091.0}],
#    'words': [{'text': '1',
#      'bounding_box': [{'x': 1228.0, 'y': 1073.0},
#       {'x': 1238.0, 'y': 1074.0},
#       {'x': 1236.0, 'y': 1092.0},
#       {'x': 1226.0, 'y': 1091.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$4.99',
#    'bounding_box': [{'x': 1346.0, 'y': 1071.0},
#     {'x': 1411.0, 'y': 1071.0},
#     {'x': 1410.0, 'y': 1094.0},
#     {'x': 1347.0, 'y': 1094.0}],
#    'words': [{'text': '$4.99',
#      'bounding_box': [{'x': 1347.0, 'y': 1071.0},
#       {'x': 1410.0, 'y': 1071.0},
#       {'x': 1410.0, 'y': 1094.0},
#       {'x': 1347.0, 'y': 1094.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'SUBTOTAL',
#    'bounding_box': [{'x': 740.0, 'y': 1144.0},
#     {'x': 847.0, 'y': 1144.0},
#     {'x': 847.0, 'y': 1164.0},
#     {'x': 740.0, 'y': 1164.0}],
#    'words': [{'text': 'SUBTOTAL',
#      'bounding_box': [{'x': 741.0, 'y': 1144.0},
#       {'x': 846.0, 'y': 1145.0},
#       {'x': 846.0, 'y': 1164.0},
#       {'x': 741.0, 'y': 1164.0}],
#      'confidence': 0.982,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$14.97',
#    'bounding_box': [{'x': 1333.0, 'y': 1140.0},
#     {'x': 1411.0, 'y': 1140.0},
#     {'x': 1411.0, 'y': 1164.0},
#     {'x': 1333.0, 'y': 1164.0}],
#    'words': [{'text': '$14.97',
#      'bounding_box': [{'x': 1333.0, 'y': 1141.0},
#       {'x': 1411.0, 'y': 1141.0},
#       {'x': 1411.0, 'y': 1164.0},
#       {'x': 1334.0, 'y': 1165.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'TAX (9%)',
#    'bounding_box': [{'x': 742.0, 'y': 1185.0},
#     {'x': 830.0, 'y': 1186.0},
#     {'x': 830.0, 'y': 1208.0},
#     {'x': 742.0, 'y': 1207.0}],
#    'words': [{'text': 'TAX',
#      'bounding_box': [{'x': 742.0, 'y': 1185.0},
#       {'x': 779.0, 'y': 1186.0},
#       {'x': 778.0, 'y': 1208.0},
#       {'x': 742.0, 'y': 1207.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '(9%)',
#      'bounding_box': [{'x': 785.0, 'y': 1186.0},
#       {'x': 831.0, 'y': 1186.0},
#       {'x': 830.0, 'y': 1209.0},
#       {'x': 784.0, 'y': 1208.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$1.35',
#    'bounding_box': [{'x': 1347.0, 'y': 1181.0},
#     {'x': 1413.0, 'y': 1181.0},
#     {'x': 1413.0, 'y': 1203.0},
#     {'x': 1348.0, 'y': 1204.0}],
#    'words': [{'text': '$1.35',
#      'bounding_box': [{'x': 1348.0, 'y': 1181.0},
#       {'x': 1410.0, 'y': 1181.0},
#       {'x': 1411.0, 'y': 1204.0},
#       {'x': 1348.0, 'y': 1204.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'TOTAL',
#    'bounding_box': [{'x': 741.0, 'y': 1256.0},
#     {'x': 808.0, 'y': 1255.0},
#     {'x': 808.0, 'y': 1275.0},
#     {'x': 741.0, 'y': 1275.0}],
#    'words': [{'text': 'TOTAL',
#      'bounding_box': [{'x': 741.0, 'y': 1256.0},
#       {'x': 804.0, 'y': 1256.0},
#       {'x': 804.0, 'y': 1276.0},
#       {'x': 741.0, 'y': 1276.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$16.32',
#    'bounding_box': [{'x': 1332.0, 'y': 1251.0},
#     {'x': 1411.0, 'y': 1251.0},
#     {'x': 1412.0, 'y': 1274.0},
#     {'x': 1332.0, 'y': 1274.0}],
#    'words': [{'text': '$16.32',
#      'bounding_box': [{'x': 1334.0, 'y': 1251.0},
#       {'x': 1410.0, 'y': 1251.0},
#       {'x': 1409.0, 'y': 1275.0},
#       {'x': 1334.0, 'y': 1275.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'BALANCE',
#    'bounding_box': [{'x': 741.0, 'y': 1324.0},
#     {'x': 839.0, 'y': 1323.0},
#     {'x': 839.0, 'y': 1343.0},
#     {'x': 741.0, 'y': 1344.0}],
#    'words': [{'text': 'BALANCE',
#      'bounding_box': [{'x': 741.0, 'y': 1325.0},
#       {'x': 834.0, 'y': 1324.0},
#       {'x': 833.0, 'y': 1344.0},
#       {'x': 741.0, 'y': 1344.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'USD $16.32',
#    'bounding_box': [{'x': 1239.0, 'y': 1333.0},
#     {'x': 1413.0, 'y': 1333.0},
#     {'x': 1413.0, 'y': 1363.0},
#     {'x': 1239.0, 'y': 1363.0}],
#    'words': [{'text': 'USD',
#      'bounding_box': [{'x': 1240.0, 'y': 1334.0},
#       {'x': 1294.0, 'y': 1334.0},
#       {'x': 1294.0, 'y': 1362.0},
#       {'x': 1240.0, 'y': 1363.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '$16.32',
#      'bounding_box': [{'x': 1304.0, 'y': 1333.0},
#       {'x': 1409.0, 'y': 1333.0},
#       {'x': 1409.0, 'y': 1364.0},
#       {'x': 1304.0, 'y': 1362.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DUE',
#    'bounding_box': [{'x': 741.0, 'y': 1355.0},
#     {'x': 784.0, 'y': 1354.0},
#     {'x': 784.0, 'y': 1373.0},
#     {'x': 741.0, 'y': 1373.0}],
#    'words': [{'text': 'DUE',
#      'bounding_box': [{'x': 741.0, 'y': 1354.0},
#       {'x': 778.0, 'y': 1354.0},
#       {'x': 778.0, 'y': 1373.0},
#       {'x': 741.0, 'y': 1373.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}}],
#  'selection_marks': []}

# %% [markdown]
# ### Accessing all the Lines

# %%
len(content.lines)
# Out:
# 47

# %%
len(content.tables)
# Out:
# 1

# %%
## Exploring content Object.
content.lines
# Out:
# [FormLine(text=INVOICE, bounding_box=[Point(x=1328.0, y=34.0), Point(x=1414.0, y=33.0), Point(x=1414.0, y=53.0), Point(x=1328.0, y=54.0)], words=[FormWord(text=INVOICE, bounding_box=[Point(x=1329.0, y=34.0), Point(x=1409.0, y=34.0), Point(x=1409.0, y=54.0), Point(x=1328.0, y=54.0)], confidence=0.995, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=Champion Store, bounding_box=[Point(x=377.0, y=88.0), Point(x=641.0, y=88.0), Point(x=641.0, y=122.0), Point(x=377.0, y=122.0)], words=[FormWord(text=Champion, bounding_box=[Point(x=378.0, y=88.0), Point(x=540.0, y=89.0), Point(x=539.0, y=123.0), Point(x=378.0, y=122.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=Store, bounding_box=[Point(x=550.0, y=89.0), Point(x=638.0, y=90.0), Point(x=638.0, y=121.0), Point(x=549.0, y=123.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=K34545455, bounding_box=[Point(x=1282.0, y=71.0), Point(x=1412.0, y=71.0), Point(x=1412.0, y=94.0), Point(x=1282.0, y=94.0)], words=[FormWord(text=K34545455, bounding_box=[Point(x=1282.0, y=72.0), Point(x=1410.0, y=72.0), Point(x=1410.0, y=95.0), Point(x=1282.0, y=94.0)], confidence=0.986, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=Business Number 22323232-24, bounding_box=[Point(x=378.0, y=145.0), Point(x=738.0, y=144.0), Point(x=738.0, y=168.0), Point(x=378.0, y=169.0)], words=[FormWord(text=Business, bounding_box=[Point(x=378.0, y=146.0), Point(x=479.0, y=146.0), Point(x=480.0, y=170.0), Point(x=378.0, y=169.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=Number, bounding_box=[Point(x=484.0, y=146.0), Point(x=581.0, y=145.0), Point(x=581.0, y=170.0), Point(x=484.0, y=170.0)], confidence=0.996, page_number=1, kind=word), FormWord(text=22323232-24, bounding_box=[Point(x=586.0, y=145.0), Point(x=735.0, y=145.0), Point(x=735.0, y=169.0), Point(x=586.0, y=170.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=DATE, bounding_box=[Point(x=1358.0, y=130.0), Point(x=1413.0, y=130.0), Point(x=1412.0, y=149.0), Point(x=1358.0, y=150.0)], words=[FormWord(text=DATE, bounding_box=[Point(x=1358.0, y=130.0), Point(x=1409.0, y=130.0), Point(x=1409.0, y=150.0), Point(x=1358.0, y=150.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=65 Longhorn Ave, bounding_box=[Point(x=378.0, y=184.0), Point(x=570.0, y=185.0), Point(x=570.0, y=211.0), Point(x=378.0, y=211.0)], words=[FormWord(text=65, bounding_box=[Point(x=379.0, y=185.0), Point(x=404.0, y=185.0), Point(x=405.0, y=211.0), Point(x=380.0, y=211.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=Longhorn, bounding_box=[Point(x=409.0, y=185.0), Point(x=518.0, y=185.0), Point(x=518.0, y=212.0), Point(x=410.0, y=211.0)], confidence=0.995, page_number=1, kind=word), FormWord(text=Ave, bounding_box=[Point(x=523.0, y=185.0), Point(x=568.0, y=185.0), Point(x=569.0, y=211.0), Point(x=523.0, y=212.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=Aug 2, 2021, bounding_box=[Point(x=1278.0, y=168.0), Point(x=1412.0, y=166.0), Point(x=1412.0, y=192.0), Point(x=1279.0, y=194.0)], words=[FormWord(text=Aug, bounding_box=[Point(x=1279.0, y=169.0), Point(x=1322.0, y=168.0), Point(x=1322.0, y=194.0), Point(x=1279.0, y=194.0)], confidence=0.997, page_number=1, kind=word), FormWord(text=2,, bounding_box=[Point(x=1327.0, y=168.0), Point(x=1348.0, y=168.0), Point(x=1348.0, y=194.0), Point(x=1327.0, y=194.0)], confidence=0.996, page_number=1, kind=word), FormWord(text=2021, bounding_box=[Point(x=1353.0, y=168.0), Point(x=1411.0, y=167.0), Point(x=1411.0, y=193.0), Point(x=1353.0, y=194.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=San Mateo, bounding_box=[Point(x=378.0, y=225.0), Point(x=499.0, y=225.0), Point(x=499.0, y=248.0), Point(x=378.0, y=248.0)], words=[FormWord(text=San, bounding_box=[Point(x=380.0, y=226.0), Point(x=418.0, y=226.0), Point(x=418.0, y=249.0), Point(x=380.0, y=249.0)], confidence=0.997, page_number=1, kind=word), FormWord(text=Mateo, bounding_box=[Point(x=423.0, y=226.0), Point(x=497.0, y=226.0), Point(x=496.0, y=249.0), Point(x=423.0, y=249.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=DUE, bounding_box=[Point(x=1371.0, y=226.0), Point(x=1413.0, y=226.0), Point(x=1413.0, y=245.0), Point(x=1371.0, y=245.0)], words=[FormWord(text=DUE, bounding_box=[Point(x=1371.0, y=226.0), Point(x=1410.0, y=226.0), Point(x=1410.0, y=245.0), Point(x=1371.0, y=245.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=94401, bounding_box=[Point(x=378.0, y=267.0), Point(x=449.0, y=266.0), Point(x=449.0, y=289.0), Point(x=378.0, y=290.0)], words=[FormWord(text=94401, bounding_box=[Point(x=379.0, y=268.0), Point(x=449.0, y=267.0), Point(x=449.0, y=290.0), Point(x=379.0, y=290.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=On Receipt, bounding_box=[Point(x=1291.0, y=261.0), Point(x=1415.0, y=262.0), Point(x=1415.0, y=291.0), Point(x=1291.0, y=290.0)], words=[FormWord(text=On, bounding_box=[Point(x=1292.0, y=262.0), Point(x=1317.0, y=262.0), Point(x=1318.0, y=291.0), Point(x=1292.0, y=291.0)], confidence=0.996, page_number=1, kind=word), FormWord(text=Receipt, bounding_box=[Point(x=1323.0, y=262.0), Point(x=1414.0, y=262.0), Point(x=1415.0, y=292.0), Point(x=1324.0, y=291.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=4084352313, bounding_box=[Point(x=377.0, y=304.0), Point(x=522.0, y=304.0), Point(x=522.0, y=332.0), Point(x=377.0, y=332.0)], words=[FormWord(text=4084352313, bounding_box=[Point(x=378.0, y=305.0), Point(x=522.0, y=305.0), Point(x=522.0, y=333.0), Point(x=378.0, y=333.0)], confidence=0.986, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=BALANCE DUE, bounding_box=[Point(x=1268.0, y=322.0), Point(x=1413.0, y=322.0), Point(x=1414.0, y=341.0), Point(x=1268.0, y=342.0)], words=[FormWord(text=BALANCE, bounding_box=[Point(x=1269.0, y=323.0), Point(x=1364.0, y=322.0), Point(x=1363.0, y=342.0), Point(x=1269.0, y=343.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=DUE, bounding_box=[Point(x=1368.0, y=322.0), Point(x=1409.0, y=322.0), Point(x=1409.0, y=342.0), Point(x=1368.0, y=342.0)], confidence=0.997, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=champstore@gmail.com, bounding_box=[Point(x=379.0, y=348.0), Point(x=655.0, y=347.0), Point(x=655.0, y=373.0), Point(x=379.0, y=374.0)], words=[FormWord(text=champstore@gmail.com, bounding_box=[Point(x=379.0, y=349.0), Point(x=644.0, y=349.0), Point(x=643.0, y=373.0), Point(x=380.0, y=373.0)], confidence=0.938, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=USD $16.32, bounding_box=[Point(x=1279.0, y=359.0), Point(x=1413.0, y=359.0), Point(x=1413.0, y=382.0), Point(x=1279.0, y=382.0)], words=[FormWord(text=USD, bounding_box=[Point(x=1279.0, y=360.0), Point(x=1322.0, y=359.0), Point(x=1322.0, y=383.0), Point(x=1280.0, y=383.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=$16.32, bounding_box=[Point(x=1331.0, y=359.0), Point(x=1410.0, y=359.0), Point(x=1410.0, y=383.0), Point(x=1332.0, y=383.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=BILL TO, bounding_box=[Point(x=70.0, y=496.0), Point(x=147.0, y=496.0), Point(x=147.0, y=515.0), Point(x=70.0, y=516.0)], words=[FormWord(text=BILL, bounding_box=[Point(x=70.0, y=497.0), Point(x=111.0, y=496.0), Point(x=111.0, y=516.0), Point(x=70.0, y=517.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=TO, bounding_box=[Point(x=118.0, y=496.0), Point(x=141.0, y=496.0), Point(x=141.0, y=516.0), Point(x=117.0, y=516.0)], confidence=0.998, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=James Starter, bounding_box=[Point(x=69.0, y=543.0), Point(x=277.0, y=543.0), Point(x=277.0, y=571.0), Point(x=69.0, y=570.0)], words=[FormWord(text=James, bounding_box=[Point(x=70.0, y=543.0), Point(x=165.0, y=543.0), Point(x=165.0, y=571.0), Point(x=71.0, y=571.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=Starter, bounding_box=[Point(x=173.0, y=543.0), Point(x=276.0, y=545.0), Point(x=276.0, y=571.0), Point(x=173.0, y=571.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=3212 Leghorn Rd, bounding_box=[Point(x=69.0, y=597.0), Point(x=264.0, y=597.0), Point(x=264.0, y=623.0), Point(x=69.0, y=623.0)], words=[FormWord(text=3212, bounding_box=[Point(x=70.0, y=597.0), Point(x=124.0, y=597.0), Point(x=124.0, y=624.0), Point(x=70.0, y=622.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=Leghorn, bounding_box=[Point(x=129.0, y=597.0), Point(x=223.0, y=597.0), Point(x=223.0, y=624.0), Point(x=129.0, y=624.0)], confidence=0.996, page_number=1, kind=word), FormWord(text=Rd, bounding_box=[Point(x=228.0, y=597.0), Point(x=260.0, y=597.0), Point(x=259.0, y=623.0), Point(x=227.0, y=624.0)], confidence=0.997, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=Mountain View, bounding_box=[Point(x=71.0, y=638.0), Point(x=239.0, y=637.0), Point(x=239.0, y=660.0), Point(x=71.0, y=661.0)], words=[FormWord(text=Mountain, bounding_box=[Point(x=72.0, y=638.0), Point(x=174.0, y=638.0), Point(x=174.0, y=661.0), Point(x=72.0, y=662.0)], confidence=0.995, page_number=1, kind=word), FormWord(text=View, bounding_box=[Point(x=181.0, y=638.0), Point(x=231.0, y=638.0), Point(x=230.0, y=661.0), Point(x=180.0, y=661.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=94040, bounding_box=[Point(x=69.0, y=679.0), Point(x=143.0, y=679.0), Point(x=143.0, y=701.0), Point(x=69.0, y=702.0)], words=[FormWord(text=94040, bounding_box=[Point(x=71.0, y=680.0), Point(x=139.0, y=679.0), Point(x=139.0, y=702.0), Point(x=71.0, y=702.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=4087031332, bounding_box=[Point(x=71.0, y=719.0), Point(x=214.0, y=718.0), Point(x=214.0, y=742.0), Point(x=71.0, y=742.0)], words=[FormWord(text=4087031332, bounding_box=[Point(x=72.0, y=720.0), Point(x=210.0, y=719.0), Point(x=210.0, y=743.0), Point(x=72.0, y=742.0)], confidence=0.991, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=james_starter@email.com, bounding_box=[Point(x=66.0, y=760.0), Point(x=364.0, y=759.0), Point(x=364.0, y=785.0), Point(x=66.0, y=785.0)], words=[FormWord(text=james_starter@email.com, bounding_box=[Point(x=68.0, y=761.0), Point(x=355.0, y=760.0), Point(x=355.0, y=785.0), Point(x=69.0, y=786.0)], confidence=0.832, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=DESCRIPTION, bounding_box=[Point(x=70.0, y=866.0), Point(x=209.0, y=866.0), Point(x=210.0, y=885.0), Point(x=70.0, y=886.0)], words=[FormWord(text=DESCRIPTION, bounding_box=[Point(x=70.0, y=867.0), Point(x=203.0, y=866.0), Point(x=203.0, y=886.0), Point(x=71.0, y=887.0)], confidence=0.991, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=RATE, bounding_box=[Point(x=1073.0, y=867.0), Point(x=1128.0, y=866.0), Point(x=1128.0, y=885.0), Point(x=1073.0, y=885.0)], words=[FormWord(text=RATE, bounding_box=[Point(x=1073.0, y=866.0), Point(x=1123.0, y=866.0), Point(x=1123.0, y=885.0), Point(x=1073.0, y=885.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=QTY, bounding_box=[Point(x=1196.0, y=867.0), Point(x=1242.0, y=866.0), Point(x=1242.0, y=885.0), Point(x=1197.0, y=887.0)], words=[FormWord(text=QTY, bounding_box=[Point(x=1196.0, y=867.0), Point(x=1237.0, y=866.0), Point(x=1238.0, y=886.0), Point(x=1197.0, y=887.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=AMOUNT, bounding_box=[Point(x=1319.0, y=867.0), Point(x=1412.0, y=866.0), Point(x=1412.0, y=885.0), Point(x=1319.0, y=886.0)], words=[FormWord(text=AMOUNT, bounding_box=[Point(x=1320.0, y=867.0), Point(x=1409.0, y=866.0), Point(x=1409.0, y=886.0), Point(x=1320.0, y=886.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=Burger, bounding_box=[Point(x=69.0, y=931.0), Point(x=145.0, y=933.0), Point(x=145.0, y=958.0), Point(x=69.0, y=957.0)], words=[FormWord(text=Burger, bounding_box=[Point(x=70.0, y=932.0), Point(x=144.0, y=933.0), Point(x=144.0, y=958.0), Point(x=69.0, y=957.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$6.99, bounding_box=[Point(x=1061.0, y=930.0), Point(x=1125.0, y=930.0), Point(x=1125.0, y=953.0), Point(x=1062.0, y=955.0)], words=[FormWord(text=$6.99, bounding_box=[Point(x=1062.0, y=930.0), Point(x=1124.0, y=930.0), Point(x=1124.0, y=954.0), Point(x=1062.0, y=955.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=1, bounding_box=[Point(x=1225.0, y=933.0), Point(x=1241.0, y=935.0), Point(x=1240.0, y=953.0), Point(x=1224.0, y=951.0)], words=[FormWord(text=1, bounding_box=[Point(x=1228.0, y=933.0), Point(x=1239.0, y=935.0), Point(x=1236.0, y=952.0), Point(x=1226.0, y=951.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=handwriting, style_confidence=0.357)),
#  FormLine(text=$6.99, bounding_box=[Point(x=1347.0, y=931.0), Point(x=1412.0, y=931.0), Point(x=1412.0, y=953.0), Point(x=1348.0, y=955.0)], words=[FormWord(text=$6.99, bounding_box=[Point(x=1348.0, y=931.0), Point(x=1410.0, y=931.0), Point(x=1410.0, y=954.0), Point(x=1348.0, y=955.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=Drink, bounding_box=[Point(x=70.0, y=1001.0), Point(x=129.0, y=1001.0), Point(x=128.0, y=1024.0), Point(x=70.0, y=1023.0)], words=[FormWord(text=Drink, bounding_box=[Point(x=70.0, y=1001.0), Point(x=127.0, y=1001.0), Point(x=127.0, y=1024.0), Point(x=70.0, y=1023.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$2.99, bounding_box=[Point(x=1061.0, y=1001.0), Point(x=1125.0, y=1000.0), Point(x=1125.0, y=1022.0), Point(x=1062.0, y=1024.0)], words=[FormWord(text=$2.99, bounding_box=[Point(x=1062.0, y=1001.0), Point(x=1123.0, y=1000.0), Point(x=1124.0, y=1023.0), Point(x=1062.0, y=1024.0)], confidence=0.986, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=1, bounding_box=[Point(x=1224.0, y=1004.0), Point(x=1241.0, y=1004.0), Point(x=1241.0, y=1024.0), Point(x=1224.0, y=1023.0)], words=[FormWord(text=1, bounding_box=[Point(x=1226.0, y=1004.0), Point(x=1238.0, y=1004.0), Point(x=1237.0, y=1024.0), Point(x=1226.0, y=1024.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$2.99, bounding_box=[Point(x=1347.0, y=1001.0), Point(x=1410.0, y=1000.0), Point(x=1410.0, y=1022.0), Point(x=1347.0, y=1025.0)], words=[FormWord(text=$2.99, bounding_box=[Point(x=1347.0, y=1001.0), Point(x=1409.0, y=1000.0), Point(x=1409.0, y=1023.0), Point(x=1348.0, y=1025.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=Icecreame, bounding_box=[Point(x=70.0, y=1073.0), Point(x=190.0, y=1073.0), Point(x=189.0, y=1094.0), Point(x=70.0, y=1093.0)], words=[FormWord(text=Icecreame, bounding_box=[Point(x=71.0, y=1073.0), Point(x=185.0, y=1074.0), Point(x=186.0, y=1095.0), Point(x=71.0, y=1094.0)], confidence=0.748, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$4.99, bounding_box=[Point(x=1061.0, y=1071.0), Point(x=1127.0, y=1070.0), Point(x=1127.0, y=1093.0), Point(x=1062.0, y=1095.0)], words=[FormWord(text=$4.99, bounding_box=[Point(x=1062.0, y=1071.0), Point(x=1125.0, y=1070.0), Point(x=1126.0, y=1094.0), Point(x=1062.0, y=1095.0)], confidence=0.981, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=1, bounding_box=[Point(x=1226.0, y=1073.0), Point(x=1241.0, y=1075.0), Point(x=1240.0, y=1093.0), Point(x=1225.0, y=1091.0)], words=[FormWord(text=1, bounding_box=[Point(x=1228.0, y=1073.0), Point(x=1238.0, y=1074.0), Point(x=1236.0, y=1092.0), Point(x=1226.0, y=1091.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$4.99, bounding_box=[Point(x=1346.0, y=1071.0), Point(x=1411.0, y=1071.0), Point(x=1410.0, y=1094.0), Point(x=1347.0, y=1094.0)], words=[FormWord(text=$4.99, bounding_box=[Point(x=1347.0, y=1071.0), Point(x=1410.0, y=1071.0), Point(x=1410.0, y=1094.0), Point(x=1347.0, y=1094.0)], confidence=0.991, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=SUBTOTAL, bounding_box=[Point(x=740.0, y=1144.0), Point(x=847.0, y=1144.0), Point(x=847.0, y=1164.0), Point(x=740.0, y=1164.0)], words=[FormWord(text=SUBTOTAL, bounding_box=[Point(x=741.0, y=1144.0), Point(x=846.0, y=1145.0), Point(x=846.0, y=1164.0), Point(x=741.0, y=1164.0)], confidence=0.982, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$14.97, bounding_box=[Point(x=1333.0, y=1140.0), Point(x=1411.0, y=1140.0), Point(x=1411.0, y=1164.0), Point(x=1333.0, y=1164.0)], words=[FormWord(text=$14.97, bounding_box=[Point(x=1333.0, y=1141.0), Point(x=1411.0, y=1141.0), Point(x=1411.0, y=1164.0), Point(x=1334.0, y=1165.0)], confidence=0.991, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=TAX (9%), bounding_box=[Point(x=742.0, y=1185.0), Point(x=830.0, y=1186.0), Point(x=830.0, y=1208.0), Point(x=742.0, y=1207.0)], words=[FormWord(text=TAX, bounding_box=[Point(x=742.0, y=1185.0), Point(x=779.0, y=1186.0), Point(x=778.0, y=1208.0), Point(x=742.0, y=1207.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=(9%), bounding_box=[Point(x=785.0, y=1186.0), Point(x=831.0, y=1186.0), Point(x=830.0, y=1209.0), Point(x=784.0, y=1208.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$1.35, bounding_box=[Point(x=1347.0, y=1181.0), Point(x=1413.0, y=1181.0), Point(x=1413.0, y=1203.0), Point(x=1348.0, y=1204.0)], words=[FormWord(text=$1.35, bounding_box=[Point(x=1348.0, y=1181.0), Point(x=1410.0, y=1181.0), Point(x=1411.0, y=1204.0), Point(x=1348.0, y=1204.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=TOTAL, bounding_box=[Point(x=741.0, y=1256.0), Point(x=808.0, y=1255.0), Point(x=808.0, y=1275.0), Point(x=741.0, y=1275.0)], words=[FormWord(text=TOTAL, bounding_box=[Point(x=741.0, y=1256.0), Point(x=804.0, y=1256.0), Point(x=804.0, y=1276.0), Point(x=741.0, y=1276.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=$16.32, bounding_box=[Point(x=1332.0, y=1251.0), Point(x=1411.0, y=1251.0), Point(x=1412.0, y=1274.0), Point(x=1332.0, y=1274.0)], words=[FormWord(text=$16.32, bounding_box=[Point(x=1334.0, y=1251.0), Point(x=1410.0, y=1251.0), Point(x=1409.0, y=1275.0), Point(x=1334.0, y=1275.0)], confidence=0.996, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=BALANCE, bounding_box=[Point(x=741.0, y=1324.0), Point(x=839.0, y=1323.0), Point(x=839.0, y=1343.0), Point(x=741.0, y=1344.0)], words=[FormWord(text=BALANCE, bounding_box=[Point(x=741.0, y=1325.0), Point(x=834.0, y=1324.0), Point(x=833.0, y=1344.0), Point(x=741.0, y=1344.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=USD $16.32, bounding_box=[Point(x=1239.0, y=1333.0), Point(x=1413.0, y=1333.0), Point(x=1413.0, y=1363.0), Point(x=1239.0, y=1363.0)], words=[FormWord(text=USD, bounding_box=[Point(x=1240.0, y=1334.0), Point(x=1294.0, y=1334.0), Point(x=1294.0, y=1362.0), Point(x=1240.0, y=1363.0)], confidence=0.994, page_number=1, kind=word), FormWord(text=$16.32, bounding_box=[Point(x=1304.0, y=1333.0), Point(x=1409.0, y=1333.0), Point(x=1409.0, y=1364.0), Point(x=1304.0, y=1362.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878)),
#  FormLine(text=DUE, bounding_box=[Point(x=741.0, y=1355.0), Point(x=784.0, y=1354.0), Point(x=784.0, y=1373.0), Point(x=741.0, y=1373.0)], words=[FormWord(text=DUE, bounding_box=[Point(x=741.0, y=1354.0), Point(x=778.0, y=1354.0), Point(x=778.0, y=1373.0), Point(x=741.0, y=1373.0)], confidence=0.994, page_number=1, kind=word)], page_number=1, kind=line, appearance=TextAppearance(style_name=other, style_confidence=0.878))]

# %%
content.to_dict()
# Out:
# {'page_number': 1,
#  'text_angle': -0.1591,
#  'width': 1486.0,
#  'height': 1740.0,
#  'unit': 'pixel',
#  'tables': [{'page_number': 1,
#    'row_count': 4,
#    'column_count': 4,
#    'cells': [{'text': 'DESCRIPTION',
#      'row_index': 0,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 61.0, 'y': 839.0},
#       {'x': 634.0, 'y': 841.0},
#       {'x': 634.0, 'y': 909.0},
#       {'x': 61.0, 'y': 907.0}],
#      'field_elements': [{'text': 'DESCRIPTION',
#        'bounding_box': [{'x': 70.0, 'y': 867.0},
#         {'x': 203.0, 'y': 866.0},
#         {'x': 203.0, 'y': 886.0},
#         {'x': 71.0, 'y': 887.0}],
#        'confidence': 0.991,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'RATE',
#      'row_index': 0,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 634.0, 'y': 841.0},
#       {'x': 1162.0, 'y': 839.0},
#       {'x': 1163.0, 'y': 909.0},
#       {'x': 634.0, 'y': 909.0}],
#      'field_elements': [{'text': 'RATE',
#        'bounding_box': [{'x': 1073.0, 'y': 866.0},
#         {'x': 1123.0, 'y': 866.0},
#         {'x': 1123.0, 'y': 885.0},
#         {'x': 1073.0, 'y': 885.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'QTY',
#      'row_index': 0,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1162.0, 'y': 839.0},
#       {'x': 1280.0, 'y': 839.0},
#       {'x': 1280.0, 'y': 909.0},
#       {'x': 1163.0, 'y': 909.0}],
#      'field_elements': [{'text': 'QTY',
#        'bounding_box': [{'x': 1196.0, 'y': 867.0},
#         {'x': 1237.0, 'y': 866.0},
#         {'x': 1238.0, 'y': 886.0},
#         {'x': 1197.0, 'y': 887.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'AMOUNT',
#      'row_index': 0,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': True,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 839.0},
#       {'x': 1421.0, 'y': 839.0},
#       {'x': 1421.0, 'y': 909.0},
#       {'x': 1280.0, 'y': 909.0}],
#      'field_elements': [{'text': 'AMOUNT',
#        'bounding_box': [{'x': 1320.0, 'y': 867.0},
#         {'x': 1409.0, 'y': 866.0},
#         {'x': 1409.0, 'y': 886.0},
#         {'x': 1320.0, 'y': 886.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Burger',
#      'row_index': 1,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 61.0, 'y': 907.0},
#       {'x': 634.0, 'y': 909.0},
#       {'x': 636.0, 'y': 978.0},
#       {'x': 60.0, 'y': 978.0}],
#      'field_elements': [{'text': 'Burger',
#        'bounding_box': [{'x': 70.0, 'y': 932.0},
#         {'x': 144.0, 'y': 933.0},
#         {'x': 144.0, 'y': 958.0},
#         {'x': 69.0, 'y': 957.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$6.99',
#      'row_index': 1,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 634.0, 'y': 909.0},
#       {'x': 1163.0, 'y': 909.0},
#       {'x': 1163.0, 'y': 978.0},
#       {'x': 636.0, 'y': 978.0}],
#      'field_elements': [{'text': '$6.99',
#        'bounding_box': [{'x': 1062.0, 'y': 930.0},
#         {'x': 1124.0, 'y': 930.0},
#         {'x': 1124.0, 'y': 954.0},
#         {'x': 1062.0, 'y': 955.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1',
#      'row_index': 1,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1163.0, 'y': 909.0},
#       {'x': 1280.0, 'y': 909.0},
#       {'x': 1280.0, 'y': 978.0},
#       {'x': 1163.0, 'y': 978.0}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1228.0, 'y': 933.0},
#         {'x': 1239.0, 'y': 935.0},
#         {'x': 1236.0, 'y': 952.0},
#         {'x': 1226.0, 'y': 951.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$6.99',
#      'row_index': 1,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 909.0},
#       {'x': 1421.0, 'y': 909.0},
#       {'x': 1421.0, 'y': 978.0},
#       {'x': 1280.0, 'y': 978.0}],
#      'field_elements': [{'text': '$6.99',
#        'bounding_box': [{'x': 1348.0, 'y': 931.0},
#         {'x': 1410.0, 'y': 931.0},
#         {'x': 1410.0, 'y': 954.0},
#         {'x': 1348.0, 'y': 955.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Drink',
#      'row_index': 2,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 60.0, 'y': 978.0},
#       {'x': 636.0, 'y': 978.0},
#       {'x': 636.0, 'y': 1049.0},
#       {'x': 60.0, 'y': 1049.0}],
#      'field_elements': [{'text': 'Drink',
#        'bounding_box': [{'x': 70.0, 'y': 1001.0},
#         {'x': 127.0, 'y': 1001.0},
#         {'x': 127.0, 'y': 1024.0},
#         {'x': 70.0, 'y': 1023.0}],
#        'confidence': 0.994,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$2.99',
#      'row_index': 2,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 636.0, 'y': 978.0},
#       {'x': 1163.0, 'y': 978.0},
#       {'x': 1163.0, 'y': 1049.0},
#       {'x': 636.0, 'y': 1049.0}],
#      'field_elements': [{'text': '$2.99',
#        'bounding_box': [{'x': 1062.0, 'y': 1001.0},
#         {'x': 1123.0, 'y': 1000.0},
#         {'x': 1124.0, 'y': 1023.0},
#         {'x': 1062.0, 'y': 1024.0}],
#        'confidence': 0.986,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1',
#      'row_index': 2,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1163.0, 'y': 978.0},
#       {'x': 1280.0, 'y': 978.0},
#       {'x': 1280.0, 'y': 1049.0},
#       {'x': 1163.0, 'y': 1049.0}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1226.0, 'y': 1004.0},
#         {'x': 1238.0, 'y': 1004.0},
#         {'x': 1237.0, 'y': 1024.0},
#         {'x': 1226.0, 'y': 1024.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$2.99',
#      'row_index': 2,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 978.0},
#       {'x': 1421.0, 'y': 978.0},
#       {'x': 1421.0, 'y': 1049.0},
#       {'x': 1280.0, 'y': 1049.0}],
#      'field_elements': [{'text': '$2.99',
#        'bounding_box': [{'x': 1347.0, 'y': 1001.0},
#         {'x': 1409.0, 'y': 1000.0},
#         {'x': 1409.0, 'y': 1023.0},
#         {'x': 1348.0, 'y': 1025.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': 'Icecreame',
#      'row_index': 3,
#      'column_index': 0,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 60.0, 'y': 1049.0},
#       {'x': 636.0, 'y': 1049.0},
#       {'x': 636.0, 'y': 1118.0},
#       {'x': 60.0, 'y': 1118.0}],
#      'field_elements': [{'text': 'Icecreame',
#        'bounding_box': [{'x': 71.0, 'y': 1073.0},
#         {'x': 185.0, 'y': 1074.0},
#         {'x': 186.0, 'y': 1095.0},
#         {'x': 71.0, 'y': 1094.0}],
#        'confidence': 0.748,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$4.99',
#      'row_index': 3,
#      'column_index': 1,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 636.0, 'y': 1049.0},
#       {'x': 1163.0, 'y': 1049.0},
#       {'x': 1163.0, 'y': 1118.0},
#       {'x': 636.0, 'y': 1118.0}],
#      'field_elements': [{'text': '$4.99',
#        'bounding_box': [{'x': 1062.0, 'y': 1071.0},
#         {'x': 1125.0, 'y': 1070.0},
#         {'x': 1126.0, 'y': 1094.0},
#         {'x': 1062.0, 'y': 1095.0}],
#        'confidence': 0.981,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '1',
#      'row_index': 3,
#      'column_index': 2,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1163.0, 'y': 1049.0},
#       {'x': 1280.0, 'y': 1049.0},
#       {'x': 1280.0, 'y': 1118.0},
#       {'x': 1163.0, 'y': 1118.0}],
#      'field_elements': [{'text': '1',
#        'bounding_box': [{'x': 1228.0, 'y': 1073.0},
#         {'x': 1238.0, 'y': 1074.0},
#         {'x': 1236.0, 'y': 1092.0},
#         {'x': 1226.0, 'y': 1091.0}],
#        'confidence': 0.996,
#        'page_number': 1,
#        'kind': 'word'}]},
#     {'text': '$4.99',
#      'row_index': 3,
#      'column_index': 3,
#      'row_span': 1,
#      'column_span': 1,
#      'confidence': 1.0,
#      'is_header': False,
#      'is_footer': False,
#      'page_number': 1,
#      'bounding_box': [{'x': 1280.0, 'y': 1049.0},
#       {'x': 1421.0, 'y': 1049.0},
#       {'x': 1421.0, 'y': 1118.0},
#       {'x': 1280.0, 'y': 1118.0}],
#      'field_elements': [{'text': '$4.99',
#        'bounding_box': [{'x': 1347.0, 'y': 1071.0},
#         {'x': 1410.0, 'y': 1071.0},
#         {'x': 1410.0, 'y': 1094.0},
#         {'x': 1347.0, 'y': 1094.0}],
#        'confidence': 0.991,
#        'page_number': 1,
#        'kind': 'word'}]}],
#    'bounding_box': [{'x': 66.0, 'y': 836.0},
#     {'x': 1419.0, 'y': 836.0},
#     {'x': 1419.0, 'y': 1120.0},
#     {'x': 66.0, 'y': 1120.0}]}],
#  'lines': [{'text': 'INVOICE',
#    'bounding_box': [{'x': 1328.0, 'y': 34.0},
#     {'x': 1414.0, 'y': 33.0},
#     {'x': 1414.0, 'y': 53.0},
#     {'x': 1328.0, 'y': 54.0}],
#    'words': [{'text': 'INVOICE',
#      'bounding_box': [{'x': 1329.0, 'y': 34.0},
#       {'x': 1409.0, 'y': 34.0},
#       {'x': 1409.0, 'y': 54.0},
#       {'x': 1328.0, 'y': 54.0}],
#      'confidence': 0.995,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Champion Store',
#    'bounding_box': [{'x': 377.0, 'y': 88.0},
#     {'x': 641.0, 'y': 88.0},
#     {'x': 641.0, 'y': 122.0},
#     {'x': 377.0, 'y': 122.0}],
#    'words': [{'text': 'Champion',
#      'bounding_box': [{'x': 378.0, 'y': 88.0},
#       {'x': 540.0, 'y': 89.0},
#       {'x': 539.0, 'y': 123.0},
#       {'x': 378.0, 'y': 122.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Store',
#      'bounding_box': [{'x': 550.0, 'y': 89.0},
#       {'x': 638.0, 'y': 90.0},
#       {'x': 638.0, 'y': 121.0},
#       {'x': 549.0, 'y': 123.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'K34545455',
#    'bounding_box': [{'x': 1282.0, 'y': 71.0},
#     {'x': 1412.0, 'y': 71.0},
#     {'x': 1412.0, 'y': 94.0},
#     {'x': 1282.0, 'y': 94.0}],
#    'words': [{'text': 'K34545455',
#      'bounding_box': [{'x': 1282.0, 'y': 72.0},
#       {'x': 1410.0, 'y': 72.0},
#       {'x': 1410.0, 'y': 95.0},
#       {'x': 1282.0, 'y': 94.0}],
#      'confidence': 0.986,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Business Number 22323232-24',
#    'bounding_box': [{'x': 378.0, 'y': 145.0},
#     {'x': 738.0, 'y': 144.0},
#     {'x': 738.0, 'y': 168.0},
#     {'x': 378.0, 'y': 169.0}],
#    'words': [{'text': 'Business',
#      'bounding_box': [{'x': 378.0, 'y': 146.0},
#       {'x': 479.0, 'y': 146.0},
#       {'x': 480.0, 'y': 170.0},
#       {'x': 378.0, 'y': 169.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Number',
#      'bounding_box': [{'x': 484.0, 'y': 146.0},
#       {'x': 581.0, 'y': 145.0},
#       {'x': 581.0, 'y': 170.0},
#       {'x': 484.0, 'y': 170.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '22323232-24',
#      'bounding_box': [{'x': 586.0, 'y': 145.0},
#       {'x': 735.0, 'y': 145.0},
#       {'x': 735.0, 'y': 169.0},
#       {'x': 586.0, 'y': 170.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DATE',
#    'bounding_box': [{'x': 1358.0, 'y': 130.0},
#     {'x': 1413.0, 'y': 130.0},
#     {'x': 1412.0, 'y': 149.0},
#     {'x': 1358.0, 'y': 150.0}],
#    'words': [{'text': 'DATE',
#      'bounding_box': [{'x': 1358.0, 'y': 130.0},
#       {'x': 1409.0, 'y': 130.0},
#       {'x': 1409.0, 'y': 150.0},
#       {'x': 1358.0, 'y': 150.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '65 Longhorn Ave',
#    'bounding_box': [{'x': 378.0, 'y': 184.0},
#     {'x': 570.0, 'y': 185.0},
#     {'x': 570.0, 'y': 211.0},
#     {'x': 378.0, 'y': 211.0}],
#    'words': [{'text': '65',
#      'bounding_box': [{'x': 379.0, 'y': 185.0},
#       {'x': 404.0, 'y': 185.0},
#       {'x': 405.0, 'y': 211.0},
#       {'x': 380.0, 'y': 211.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Longhorn',
#      'bounding_box': [{'x': 409.0, 'y': 185.0},
#       {'x': 518.0, 'y': 185.0},
#       {'x': 518.0, 'y': 212.0},
#       {'x': 410.0, 'y': 211.0}],
#      'confidence': 0.995,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Ave',
#      'bounding_box': [{'x': 523.0, 'y': 185.0},
#       {'x': 568.0, 'y': 185.0},
#       {'x': 569.0, 'y': 211.0},
#       {'x': 523.0, 'y': 212.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Aug 2, 2021',
#    'bounding_box': [{'x': 1278.0, 'y': 168.0},
#     {'x': 1412.0, 'y': 166.0},
#     {'x': 1412.0, 'y': 192.0},
#     {'x': 1279.0, 'y': 194.0}],
#    'words': [{'text': 'Aug',
#      'bounding_box': [{'x': 1279.0, 'y': 169.0},
#       {'x': 1322.0, 'y': 168.0},
#       {'x': 1322.0, 'y': 194.0},
#       {'x': 1279.0, 'y': 194.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '2,',
#      'bounding_box': [{'x': 1327.0, 'y': 168.0},
#       {'x': 1348.0, 'y': 168.0},
#       {'x': 1348.0, 'y': 194.0},
#       {'x': 1327.0, 'y': 194.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '2021',
#      'bounding_box': [{'x': 1353.0, 'y': 168.0},
#       {'x': 1411.0, 'y': 167.0},
#       {'x': 1411.0, 'y': 193.0},
#       {'x': 1353.0, 'y': 194.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'San Mateo',
#    'bounding_box': [{'x': 378.0, 'y': 225.0},
#     {'x': 499.0, 'y': 225.0},
#     {'x': 499.0, 'y': 248.0},
#     {'x': 378.0, 'y': 248.0}],
#    'words': [{'text': 'San',
#      'bounding_box': [{'x': 380.0, 'y': 226.0},
#       {'x': 418.0, 'y': 226.0},
#       {'x': 418.0, 'y': 249.0},
#       {'x': 380.0, 'y': 249.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Mateo',
#      'bounding_box': [{'x': 423.0, 'y': 226.0},
#       {'x': 497.0, 'y': 226.0},
#       {'x': 496.0, 'y': 249.0},
#       {'x': 423.0, 'y': 249.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DUE',
#    'bounding_box': [{'x': 1371.0, 'y': 226.0},
#     {'x': 1413.0, 'y': 226.0},
#     {'x': 1413.0, 'y': 245.0},
#     {'x': 1371.0, 'y': 245.0}],
#    'words': [{'text': 'DUE',
#      'bounding_box': [{'x': 1371.0, 'y': 226.0},
#       {'x': 1410.0, 'y': 226.0},
#       {'x': 1410.0, 'y': 245.0},
#       {'x': 1371.0, 'y': 245.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '94401',
#    'bounding_box': [{'x': 378.0, 'y': 267.0},
#     {'x': 449.0, 'y': 266.0},
#     {'x': 449.0, 'y': 289.0},
#     {'x': 378.0, 'y': 290.0}],
#    'words': [{'text': '94401',
#      'bounding_box': [{'x': 379.0, 'y': 268.0},
#       {'x': 449.0, 'y': 267.0},
#       {'x': 449.0, 'y': 290.0},
#       {'x': 379.0, 'y': 290.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'On Receipt',
#    'bounding_box': [{'x': 1291.0, 'y': 261.0},
#     {'x': 1415.0, 'y': 262.0},
#     {'x': 1415.0, 'y': 291.0},
#     {'x': 1291.0, 'y': 290.0}],
#    'words': [{'text': 'On',
#      'bounding_box': [{'x': 1292.0, 'y': 262.0},
#       {'x': 1317.0, 'y': 262.0},
#       {'x': 1318.0, 'y': 291.0},
#       {'x': 1292.0, 'y': 291.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Receipt',
#      'bounding_box': [{'x': 1323.0, 'y': 262.0},
#       {'x': 1414.0, 'y': 262.0},
#       {'x': 1415.0, 'y': 292.0},
#       {'x': 1324.0, 'y': 291.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '4084352313',
#    'bounding_box': [{'x': 377.0, 'y': 304.0},
#     {'x': 522.0, 'y': 304.0},
#     {'x': 522.0, 'y': 332.0},
#     {'x': 377.0, 'y': 332.0}],
#    'words': [{'text': '4084352313',
#      'bounding_box': [{'x': 378.0, 'y': 305.0},
#       {'x': 522.0, 'y': 305.0},
#       {'x': 522.0, 'y': 333.0},
#       {'x': 378.0, 'y': 333.0}],
#      'confidence': 0.986,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'BALANCE DUE',
#    'bounding_box': [{'x': 1268.0, 'y': 322.0},
#     {'x': 1413.0, 'y': 322.0},
#     {'x': 1414.0, 'y': 341.0},
#     {'x': 1268.0, 'y': 342.0}],
#    'words': [{'text': 'BALANCE',
#      'bounding_box': [{'x': 1269.0, 'y': 323.0},
#       {'x': 1364.0, 'y': 322.0},
#       {'x': 1363.0, 'y': 342.0},
#       {'x': 1269.0, 'y': 343.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'DUE',
#      'bounding_box': [{'x': 1368.0, 'y': 322.0},
#       {'x': 1409.0, 'y': 322.0},
#       {'x': 1409.0, 'y': 342.0},
#       {'x': 1368.0, 'y': 342.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'champstore@gmail.com',
#    'bounding_box': [{'x': 379.0, 'y': 348.0},
#     {'x': 655.0, 'y': 347.0},
#     {'x': 655.0, 'y': 373.0},
#     {'x': 379.0, 'y': 374.0}],
#    'words': [{'text': 'champstore@gmail.com',
#      'bounding_box': [{'x': 379.0, 'y': 349.0},
#       {'x': 644.0, 'y': 349.0},
#       {'x': 643.0, 'y': 373.0},
#       {'x': 380.0, 'y': 373.0}],
#      'confidence': 0.938,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'USD $16.32',
#    'bounding_box': [{'x': 1279.0, 'y': 359.0},
#     {'x': 1413.0, 'y': 359.0},
#     {'x': 1413.0, 'y': 382.0},
#     {'x': 1279.0, 'y': 382.0}],
#    'words': [{'text': 'USD',
#      'bounding_box': [{'x': 1279.0, 'y': 360.0},
#       {'x': 1322.0, 'y': 359.0},
#       {'x': 1322.0, 'y': 383.0},
#       {'x': 1280.0, 'y': 383.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '$16.32',
#      'bounding_box': [{'x': 1331.0, 'y': 359.0},
#       {'x': 1410.0, 'y': 359.0},
#       {'x': 1410.0, 'y': 383.0},
#       {'x': 1332.0, 'y': 383.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'BILL TO',
#    'bounding_box': [{'x': 70.0, 'y': 496.0},
#     {'x': 147.0, 'y': 496.0},
#     {'x': 147.0, 'y': 515.0},
#     {'x': 70.0, 'y': 516.0}],
#    'words': [{'text': 'BILL',
#      'bounding_box': [{'x': 70.0, 'y': 497.0},
#       {'x': 111.0, 'y': 496.0},
#       {'x': 111.0, 'y': 516.0},
#       {'x': 70.0, 'y': 517.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'TO',
#      'bounding_box': [{'x': 118.0, 'y': 496.0},
#       {'x': 141.0, 'y': 496.0},
#       {'x': 141.0, 'y': 516.0},
#       {'x': 117.0, 'y': 516.0}],
#      'confidence': 0.998,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'James Starter',
#    'bounding_box': [{'x': 69.0, 'y': 543.0},
#     {'x': 277.0, 'y': 543.0},
#     {'x': 277.0, 'y': 571.0},
#     {'x': 69.0, 'y': 570.0}],
#    'words': [{'text': 'James',
#      'bounding_box': [{'x': 70.0, 'y': 543.0},
#       {'x': 165.0, 'y': 543.0},
#       {'x': 165.0, 'y': 571.0},
#       {'x': 71.0, 'y': 571.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Starter',
#      'bounding_box': [{'x': 173.0, 'y': 543.0},
#       {'x': 276.0, 'y': 545.0},
#       {'x': 276.0, 'y': 571.0},
#       {'x': 173.0, 'y': 571.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '3212 Leghorn Rd',
#    'bounding_box': [{'x': 69.0, 'y': 597.0},
#     {'x': 264.0, 'y': 597.0},
#     {'x': 264.0, 'y': 623.0},
#     {'x': 69.0, 'y': 623.0}],
#    'words': [{'text': '3212',
#      'bounding_box': [{'x': 70.0, 'y': 597.0},
#       {'x': 124.0, 'y': 597.0},
#       {'x': 124.0, 'y': 624.0},
#       {'x': 70.0, 'y': 622.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Leghorn',
#      'bounding_box': [{'x': 129.0, 'y': 597.0},
#       {'x': 223.0, 'y': 597.0},
#       {'x': 223.0, 'y': 624.0},
#       {'x': 129.0, 'y': 624.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'Rd',
#      'bounding_box': [{'x': 228.0, 'y': 597.0},
#       {'x': 260.0, 'y': 597.0},
#       {'x': 259.0, 'y': 623.0},
#       {'x': 227.0, 'y': 624.0}],
#      'confidence': 0.997,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Mountain View',
#    'bounding_box': [{'x': 71.0, 'y': 638.0},
#     {'x': 239.0, 'y': 637.0},
#     {'x': 239.0, 'y': 660.0},
#     {'x': 71.0, 'y': 661.0}],
#    'words': [{'text': 'Mountain',
#      'bounding_box': [{'x': 72.0, 'y': 638.0},
#       {'x': 174.0, 'y': 638.0},
#       {'x': 174.0, 'y': 661.0},
#       {'x': 72.0, 'y': 662.0}],
#      'confidence': 0.995,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': 'View',
#      'bounding_box': [{'x': 181.0, 'y': 638.0},
#       {'x': 231.0, 'y': 638.0},
#       {'x': 230.0, 'y': 661.0},
#       {'x': 180.0, 'y': 661.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '94040',
#    'bounding_box': [{'x': 69.0, 'y': 679.0},
#     {'x': 143.0, 'y': 679.0},
#     {'x': 143.0, 'y': 701.0},
#     {'x': 69.0, 'y': 702.0}],
#    'words': [{'text': '94040',
#      'bounding_box': [{'x': 71.0, 'y': 680.0},
#       {'x': 139.0, 'y': 679.0},
#       {'x': 139.0, 'y': 702.0},
#       {'x': 71.0, 'y': 702.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '4087031332',
#    'bounding_box': [{'x': 71.0, 'y': 719.0},
#     {'x': 214.0, 'y': 718.0},
#     {'x': 214.0, 'y': 742.0},
#     {'x': 71.0, 'y': 742.0}],
#    'words': [{'text': '4087031332',
#      'bounding_box': [{'x': 72.0, 'y': 720.0},
#       {'x': 210.0, 'y': 719.0},
#       {'x': 210.0, 'y': 743.0},
#       {'x': 72.0, 'y': 742.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'james_starter@email.com',
#    'bounding_box': [{'x': 66.0, 'y': 760.0},
#     {'x': 364.0, 'y': 759.0},
#     {'x': 364.0, 'y': 785.0},
#     {'x': 66.0, 'y': 785.0}],
#    'words': [{'text': 'james_starter@email.com',
#      'bounding_box': [{'x': 68.0, 'y': 761.0},
#       {'x': 355.0, 'y': 760.0},
#       {'x': 355.0, 'y': 785.0},
#       {'x': 69.0, 'y': 786.0}],
#      'confidence': 0.832,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DESCRIPTION',
#    'bounding_box': [{'x': 70.0, 'y': 866.0},
#     {'x': 209.0, 'y': 866.0},
#     {'x': 210.0, 'y': 885.0},
#     {'x': 70.0, 'y': 886.0}],
#    'words': [{'text': 'DESCRIPTION',
#      'bounding_box': [{'x': 70.0, 'y': 867.0},
#       {'x': 203.0, 'y': 866.0},
#       {'x': 203.0, 'y': 886.0},
#       {'x': 71.0, 'y': 887.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'RATE',
#    'bounding_box': [{'x': 1073.0, 'y': 867.0},
#     {'x': 1128.0, 'y': 866.0},
#     {'x': 1128.0, 'y': 885.0},
#     {'x': 1073.0, 'y': 885.0}],
#    'words': [{'text': 'RATE',
#      'bounding_box': [{'x': 1073.0, 'y': 866.0},
#       {'x': 1123.0, 'y': 866.0},
#       {'x': 1123.0, 'y': 885.0},
#       {'x': 1073.0, 'y': 885.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'QTY',
#    'bounding_box': [{'x': 1196.0, 'y': 867.0},
#     {'x': 1242.0, 'y': 866.0},
#     {'x': 1242.0, 'y': 885.0},
#     {'x': 1197.0, 'y': 887.0}],
#    'words': [{'text': 'QTY',
#      'bounding_box': [{'x': 1196.0, 'y': 867.0},
#       {'x': 1237.0, 'y': 866.0},
#       {'x': 1238.0, 'y': 886.0},
#       {'x': 1197.0, 'y': 887.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'AMOUNT',
#    'bounding_box': [{'x': 1319.0, 'y': 867.0},
#     {'x': 1412.0, 'y': 866.0},
#     {'x': 1412.0, 'y': 885.0},
#     {'x': 1319.0, 'y': 886.0}],
#    'words': [{'text': 'AMOUNT',
#      'bounding_box': [{'x': 1320.0, 'y': 867.0},
#       {'x': 1409.0, 'y': 866.0},
#       {'x': 1409.0, 'y': 886.0},
#       {'x': 1320.0, 'y': 886.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Burger',
#    'bounding_box': [{'x': 69.0, 'y': 931.0},
#     {'x': 145.0, 'y': 933.0},
#     {'x': 145.0, 'y': 958.0},
#     {'x': 69.0, 'y': 957.0}],
#    'words': [{'text': 'Burger',
#      'bounding_box': [{'x': 70.0, 'y': 932.0},
#       {'x': 144.0, 'y': 933.0},
#       {'x': 144.0, 'y': 958.0},
#       {'x': 69.0, 'y': 957.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$6.99',
#    'bounding_box': [{'x': 1061.0, 'y': 930.0},
#     {'x': 1125.0, 'y': 930.0},
#     {'x': 1125.0, 'y': 953.0},
#     {'x': 1062.0, 'y': 955.0}],
#    'words': [{'text': '$6.99',
#      'bounding_box': [{'x': 1062.0, 'y': 930.0},
#       {'x': 1124.0, 'y': 930.0},
#       {'x': 1124.0, 'y': 954.0},
#       {'x': 1062.0, 'y': 955.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '1',
#    'bounding_box': [{'x': 1225.0, 'y': 933.0},
#     {'x': 1241.0, 'y': 935.0},
#     {'x': 1240.0, 'y': 953.0},
#     {'x': 1224.0, 'y': 951.0}],
#    'words': [{'text': '1',
#      'bounding_box': [{'x': 1228.0, 'y': 933.0},
#       {'x': 1239.0, 'y': 935.0},
#       {'x': 1236.0, 'y': 952.0},
#       {'x': 1226.0, 'y': 951.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'handwriting', 'style_confidence': 0.357}},
#   {'text': '$6.99',
#    'bounding_box': [{'x': 1347.0, 'y': 931.0},
#     {'x': 1412.0, 'y': 931.0},
#     {'x': 1412.0, 'y': 953.0},
#     {'x': 1348.0, 'y': 955.0}],
#    'words': [{'text': '$6.99',
#      'bounding_box': [{'x': 1348.0, 'y': 931.0},
#       {'x': 1410.0, 'y': 931.0},
#       {'x': 1410.0, 'y': 954.0},
#       {'x': 1348.0, 'y': 955.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Drink',
#    'bounding_box': [{'x': 70.0, 'y': 1001.0},
#     {'x': 129.0, 'y': 1001.0},
#     {'x': 128.0, 'y': 1024.0},
#     {'x': 70.0, 'y': 1023.0}],
#    'words': [{'text': 'Drink',
#      'bounding_box': [{'x': 70.0, 'y': 1001.0},
#       {'x': 127.0, 'y': 1001.0},
#       {'x': 127.0, 'y': 1024.0},
#       {'x': 70.0, 'y': 1023.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$2.99',
#    'bounding_box': [{'x': 1061.0, 'y': 1001.0},
#     {'x': 1125.0, 'y': 1000.0},
#     {'x': 1125.0, 'y': 1022.0},
#     {'x': 1062.0, 'y': 1024.0}],
#    'words': [{'text': '$2.99',
#      'bounding_box': [{'x': 1062.0, 'y': 1001.0},
#       {'x': 1123.0, 'y': 1000.0},
#       {'x': 1124.0, 'y': 1023.0},
#       {'x': 1062.0, 'y': 1024.0}],
#      'confidence': 0.986,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '1',
#    'bounding_box': [{'x': 1224.0, 'y': 1004.0},
#     {'x': 1241.0, 'y': 1004.0},
#     {'x': 1241.0, 'y': 1024.0},
#     {'x': 1224.0, 'y': 1023.0}],
#    'words': [{'text': '1',
#      'bounding_box': [{'x': 1226.0, 'y': 1004.0},
#       {'x': 1238.0, 'y': 1004.0},
#       {'x': 1237.0, 'y': 1024.0},
#       {'x': 1226.0, 'y': 1024.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$2.99',
#    'bounding_box': [{'x': 1347.0, 'y': 1001.0},
#     {'x': 1410.0, 'y': 1000.0},
#     {'x': 1410.0, 'y': 1022.0},
#     {'x': 1347.0, 'y': 1025.0}],
#    'words': [{'text': '$2.99',
#      'bounding_box': [{'x': 1347.0, 'y': 1001.0},
#       {'x': 1409.0, 'y': 1000.0},
#       {'x': 1409.0, 'y': 1023.0},
#       {'x': 1348.0, 'y': 1025.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'Icecreame',
#    'bounding_box': [{'x': 70.0, 'y': 1073.0},
#     {'x': 190.0, 'y': 1073.0},
#     {'x': 189.0, 'y': 1094.0},
#     {'x': 70.0, 'y': 1093.0}],
#    'words': [{'text': 'Icecreame',
#      'bounding_box': [{'x': 71.0, 'y': 1073.0},
#       {'x': 185.0, 'y': 1074.0},
#       {'x': 186.0, 'y': 1095.0},
#       {'x': 71.0, 'y': 1094.0}],
#      'confidence': 0.748,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$4.99',
#    'bounding_box': [{'x': 1061.0, 'y': 1071.0},
#     {'x': 1127.0, 'y': 1070.0},
#     {'x': 1127.0, 'y': 1093.0},
#     {'x': 1062.0, 'y': 1095.0}],
#    'words': [{'text': '$4.99',
#      'bounding_box': [{'x': 1062.0, 'y': 1071.0},
#       {'x': 1125.0, 'y': 1070.0},
#       {'x': 1126.0, 'y': 1094.0},
#       {'x': 1062.0, 'y': 1095.0}],
#      'confidence': 0.981,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '1',
#    'bounding_box': [{'x': 1226.0, 'y': 1073.0},
#     {'x': 1241.0, 'y': 1075.0},
#     {'x': 1240.0, 'y': 1093.0},
#     {'x': 1225.0, 'y': 1091.0}],
#    'words': [{'text': '1',
#      'bounding_box': [{'x': 1228.0, 'y': 1073.0},
#       {'x': 1238.0, 'y': 1074.0},
#       {'x': 1236.0, 'y': 1092.0},
#       {'x': 1226.0, 'y': 1091.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$4.99',
#    'bounding_box': [{'x': 1346.0, 'y': 1071.0},
#     {'x': 1411.0, 'y': 1071.0},
#     {'x': 1410.0, 'y': 1094.0},
#     {'x': 1347.0, 'y': 1094.0}],
#    'words': [{'text': '$4.99',
#      'bounding_box': [{'x': 1347.0, 'y': 1071.0},
#       {'x': 1410.0, 'y': 1071.0},
#       {'x': 1410.0, 'y': 1094.0},
#       {'x': 1347.0, 'y': 1094.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'SUBTOTAL',
#    'bounding_box': [{'x': 740.0, 'y': 1144.0},
#     {'x': 847.0, 'y': 1144.0},
#     {'x': 847.0, 'y': 1164.0},
#     {'x': 740.0, 'y': 1164.0}],
#    'words': [{'text': 'SUBTOTAL',
#      'bounding_box': [{'x': 741.0, 'y': 1144.0},
#       {'x': 846.0, 'y': 1145.0},
#       {'x': 846.0, 'y': 1164.0},
#       {'x': 741.0, 'y': 1164.0}],
#      'confidence': 0.982,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$14.97',
#    'bounding_box': [{'x': 1333.0, 'y': 1140.0},
#     {'x': 1411.0, 'y': 1140.0},
#     {'x': 1411.0, 'y': 1164.0},
#     {'x': 1333.0, 'y': 1164.0}],
#    'words': [{'text': '$14.97',
#      'bounding_box': [{'x': 1333.0, 'y': 1141.0},
#       {'x': 1411.0, 'y': 1141.0},
#       {'x': 1411.0, 'y': 1164.0},
#       {'x': 1334.0, 'y': 1165.0}],
#      'confidence': 0.991,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'TAX (9%)',
#    'bounding_box': [{'x': 742.0, 'y': 1185.0},
#     {'x': 830.0, 'y': 1186.0},
#     {'x': 830.0, 'y': 1208.0},
#     {'x': 742.0, 'y': 1207.0}],
#    'words': [{'text': 'TAX',
#      'bounding_box': [{'x': 742.0, 'y': 1185.0},
#       {'x': 779.0, 'y': 1186.0},
#       {'x': 778.0, 'y': 1208.0},
#       {'x': 742.0, 'y': 1207.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '(9%)',
#      'bounding_box': [{'x': 785.0, 'y': 1186.0},
#       {'x': 831.0, 'y': 1186.0},
#       {'x': 830.0, 'y': 1209.0},
#       {'x': 784.0, 'y': 1208.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$1.35',
#    'bounding_box': [{'x': 1347.0, 'y': 1181.0},
#     {'x': 1413.0, 'y': 1181.0},
#     {'x': 1413.0, 'y': 1203.0},
#     {'x': 1348.0, 'y': 1204.0}],
#    'words': [{'text': '$1.35',
#      'bounding_box': [{'x': 1348.0, 'y': 1181.0},
#       {'x': 1410.0, 'y': 1181.0},
#       {'x': 1411.0, 'y': 1204.0},
#       {'x': 1348.0, 'y': 1204.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'TOTAL',
#    'bounding_box': [{'x': 741.0, 'y': 1256.0},
#     {'x': 808.0, 'y': 1255.0},
#     {'x': 808.0, 'y': 1275.0},
#     {'x': 741.0, 'y': 1275.0}],
#    'words': [{'text': 'TOTAL',
#      'bounding_box': [{'x': 741.0, 'y': 1256.0},
#       {'x': 804.0, 'y': 1256.0},
#       {'x': 804.0, 'y': 1276.0},
#       {'x': 741.0, 'y': 1276.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': '$16.32',
#    'bounding_box': [{'x': 1332.0, 'y': 1251.0},
#     {'x': 1411.0, 'y': 1251.0},
#     {'x': 1412.0, 'y': 1274.0},
#     {'x': 1332.0, 'y': 1274.0}],
#    'words': [{'text': '$16.32',
#      'bounding_box': [{'x': 1334.0, 'y': 1251.0},
#       {'x': 1410.0, 'y': 1251.0},
#       {'x': 1409.0, 'y': 1275.0},
#       {'x': 1334.0, 'y': 1275.0}],
#      'confidence': 0.996,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'BALANCE',
#    'bounding_box': [{'x': 741.0, 'y': 1324.0},
#     {'x': 839.0, 'y': 1323.0},
#     {'x': 839.0, 'y': 1343.0},
#     {'x': 741.0, 'y': 1344.0}],
#    'words': [{'text': 'BALANCE',
#      'bounding_box': [{'x': 741.0, 'y': 1325.0},
#       {'x': 834.0, 'y': 1324.0},
#       {'x': 833.0, 'y': 1344.0},
#       {'x': 741.0, 'y': 1344.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'USD $16.32',
#    'bounding_box': [{'x': 1239.0, 'y': 1333.0},
#     {'x': 1413.0, 'y': 1333.0},
#     {'x': 1413.0, 'y': 1363.0},
#     {'x': 1239.0, 'y': 1363.0}],
#    'words': [{'text': 'USD',
#      'bounding_box': [{'x': 1240.0, 'y': 1334.0},
#       {'x': 1294.0, 'y': 1334.0},
#       {'x': 1294.0, 'y': 1362.0},
#       {'x': 1240.0, 'y': 1363.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'},
#     {'text': '$16.32',
#      'bounding_box': [{'x': 1304.0, 'y': 1333.0},
#       {'x': 1409.0, 'y': 1333.0},
#       {'x': 1409.0, 'y': 1364.0},
#       {'x': 1304.0, 'y': 1362.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}},
#   {'text': 'DUE',
#    'bounding_box': [{'x': 741.0, 'y': 1355.0},
#     {'x': 784.0, 'y': 1354.0},
#     {'x': 784.0, 'y': 1373.0},
#     {'x': 741.0, 'y': 1373.0}],
#    'words': [{'text': 'DUE',
#      'bounding_box': [{'x': 741.0, 'y': 1354.0},
#       {'x': 778.0, 'y': 1354.0},
#       {'x': 778.0, 'y': 1373.0},
#       {'x': 741.0, 'y': 1373.0}],
#      'confidence': 0.994,
#      'page_number': 1,
#      'kind': 'word'}],
#    'page_number': 1,
#    'kind': 'line',
#    'appearance': {'style_name': 'other', 'style_confidence': 0.878}}],
#  'selection_marks': []}

# %%
print("Page has width: {} and height: {}, measured with unit: {}".format(content.width, content.height, content.unit))
# Out:
# Page has width: 1486.0 and height: 1740.0, measured with unit: pixel

# %%
# --------------------------
# Code Snippet Source 
# https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/REST/python-disk.md
# --------------------------
def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

# %% [markdown]
# ### Table

# %%
for table_idx, table in enumerate(content.tables):
    print("Table # {} has {} rows and {} columns".format(table_idx, table.row_count, table.column_count))
    print("Table # {} location on page: {}".format(table_idx, format_bounding_box(table.bounding_box)))
    for cell in table.cells:
        print("...Cell[{}][{}] has text '{}' within bounding box '{}'".format(cell.row_index, cell.column_index, cell.text, format_bounding_box(cell.bounding_box)))
# Out:
# Table # 0 has 4 rows and 4 columns
# Table # 0 location on page: [66.0, 836.0], [1419.0, 836.0], [1419.0, 1120.0], [66.0, 1120.0]
# ...Cell[0][0] has text 'DESCRIPTION' within bounding box '[61.0, 839.0], [634.0, 841.0], [634.0, 909.0], [61.0, 907.0]'
# ...Cell[0][1] has text 'RATE' within bounding box '[634.0, 841.0], [1162.0, 839.0], [1163.0, 909.0], [634.0, 909.0]'
# ...Cell[0][2] has text 'QTY' within bounding box '[1162.0, 839.0], [1280.0, 839.0], [1280.0, 909.0], [1163.0, 909.0]'
# ...Cell[0][3] has text 'AMOUNT' within bounding box '[1280.0, 839.0], [1421.0, 839.0], [1421.0, 909.0], [1280.0, 909.0]'
# ...Cell[1][0] has text 'Burger' within bounding box '[61.0, 907.0], [634.0, 909.0], [636.0, 978.0], [60.0, 978.0]'
# ...Cell[1][1] has text '$6.99' within bounding box '[634.0, 909.0], [1163.0, 909.0], [1163.0, 978.0], [636.0, 978.0]'
# ...Cell[1][2] has text '1' within bounding box '[1163.0, 909.0], [1280.0, 909.0], [1280.0, 978.0], [1163.0, 978.0]'
# ...Cell[1][3] has text '$6.99' within bounding box '[1280.0, 909.0], [1421.0, 909.0], [1421.0, 978.0], [1280.0, 978.0]'
# ...Cell[2][0] has text 'Drink' within bounding box '[60.0, 978.0], [636.0, 978.0], [636.0, 1049.0], [60.0, 1049.0]'
# ...Cell[2][1] has text '$2.99' within bounding box '[636.0, 978.0], [1163.0, 978.0], [1163.0, 1049.0], [636.0, 1049.0]'
# ...Cell[2][2] has text '1' within bounding box '[1163.0, 978.0], [1280.0, 978.0], [1280.0, 1049.0], [1163.0, 1049.0]'
# ...Cell[2][3] has text '$2.99' within bounding box '[1280.0, 978.0], [1421.0, 978.0], [1421.0, 1049.0], [1280.0, 1049.0]'
# ...Cell[3][0] has text 'Icecreame' within bounding box '[60.0, 1049.0], [636.0, 1049.0], [636.0, 1118.0], [60.0, 1118.0]'
# ...Cell[3][1] has text '$4.99' within bounding box '[636.0, 1049.0], [1163.0, 1049.0], [1163.0, 1118.0], [636.0, 1118.0]'
# ...Cell[3][2] has text '1' within bounding box '[1163.0, 1049.0], [1280.0, 1049.0], [1280.0, 1118.0], [1163.0, 1118.0]'
# ...Cell[3][3] has text '$4.99' within bounding box '[1280.0, 1049.0], [1421.0, 1049.0], [1421.0, 1118.0], [1280.0, 1118.0]'

# %% [markdown]
# ### Lines and Words

# %%
# --------------------------
# Code Snippet Source 
# https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/REST/python-disk.md
# --------------------------

for line_idx, line in enumerate(content.lines):
    print("Line # {} has word count '{}' and text '{}' within bounding box '{}'".format(
        line_idx,
        len(line.words),
        line.text,
        format_bounding_box(line.bounding_box)
    ))
    if line.appearance:
        if line.appearance.style_name == "handwriting" and line.appearance.style_confidence > 0.8:
            print("Text line '{}' is handwritten and might be a signature.".format(line.text))
    for word in line.words:
        print("...Word '{}' has a confidence of {}".format(word.text, word.confidence))
# Out:
# Line # 0 has word count '1' and text 'INVOICE' within bounding box '[1328.0, 34.0], [1414.0, 33.0], [1414.0, 53.0], [1328.0, 54.0]'
# ...Word 'INVOICE' has a confidence of 0.995
# Line # 1 has word count '2' and text 'Champion Store' within bounding box '[377.0, 88.0], [641.0, 88.0], [641.0, 122.0], [377.0, 122.0]'
# ...Word 'Champion' has a confidence of 0.994
# ...Word 'Store' has a confidence of 0.996
# Line # 2 has word count '1' and text 'K34545455' within bounding box '[1282.0, 71.0], [1412.0, 71.0], [1412.0, 94.0], [1282.0, 94.0]'
# ...Word 'K34545455' has a confidence of 0.986
# Line # 3 has word count '3' and text 'Business Number 22323232-24' within bounding box '[378.0, 145.0], [738.0, 144.0], [738.0, 168.0], [378.0, 169.0]'
# ...Word 'Business' has a confidence of 0.994
# ...Word 'Number' has a confidence of 0.996
# ...Word '22323232-24' has a confidence of 0.994
# Line # 4 has word count '1' and text 'DATE' within bounding box '[1358.0, 130.0], [1413.0, 130.0], [1412.0, 149.0], [1358.0, 150.0]'
# ...Word 'DATE' has a confidence of 0.994
# Line # 5 has word count '3' and text '65 Longhorn Ave' within bounding box '[378.0, 184.0], [570.0, 185.0], [570.0, 211.0], [378.0, 211.0]'
# ...Word '65' has a confidence of 0.994
# ...Word 'Longhorn' has a confidence of 0.995
# ...Word 'Ave' has a confidence of 0.994
# Line # 6 has word count '3' and text 'Aug 2, 2021' within bounding box '[1278.0, 168.0], [1412.0, 166.0], [1412.0, 192.0], [1279.0, 194.0]'
# ...Word 'Aug' has a confidence of 0.997
# ...Word '2,' has a confidence of 0.996
# ...Word '2021' has a confidence of 0.994
# Line # 7 has word count '2' and text 'San Mateo' within bounding box '[378.0, 225.0], [499.0, 225.0], [499.0, 248.0], [378.0, 248.0]'
# ...Word 'San' has a confidence of 0.997
# ...Word 'Mateo' has a confidence of 0.996
# Line # 8 has word count '1' and text 'DUE' within bounding box '[1371.0, 226.0], [1413.0, 226.0], [1413.0, 245.0], [1371.0, 245.0]'
# ...Word 'DUE' has a confidence of 0.994
# Line # 9 has word count '1' and text '94401' within bounding box '[378.0, 267.0], [449.0, 266.0], [449.0, 289.0], [378.0, 290.0]'
# ...Word '94401' has a confidence of 0.994
# Line # 10 has word count '2' and text 'On Receipt' within bounding box '[1291.0, 261.0], [1415.0, 262.0], [1415.0, 291.0], [1291.0, 290.0]'
# ...Word 'On' has a confidence of 0.996
# ...Word 'Receipt' has a confidence of 0.996
# Line # 11 has word count '1' and text '4084352313' within bounding box '[377.0, 304.0], [522.0, 304.0], [522.0, 332.0], [377.0, 332.0]'
# ...Word '4084352313' has a confidence of 0.986
# Line # 12 has word count '2' and text 'BALANCE DUE' within bounding box '[1268.0, 322.0], [1413.0, 322.0], [1414.0, 341.0], [1268.0, 342.0]'
# ...Word 'BALANCE' has a confidence of 0.994
# ...Word 'DUE' has a confidence of 0.997
# Line # 13 has word count '1' and text 'champstore@gmail.com' within bounding box '[379.0, 348.0], [655.0, 347.0], [655.0, 373.0], [379.0, 374.0]'
# ...Word 'champstore@gmail.com' has a confidence of 0.938
# Line # 14 has word count '2' and text 'USD $16.32' within bounding box '[1279.0, 359.0], [1413.0, 359.0], [1413.0, 382.0], [1279.0, 382.0]'
# ...Word 'USD' has a confidence of 0.994
# ...Word '$16.32' has a confidence of 0.994
# Line # 15 has word count '2' and text 'BILL TO' within bounding box '[70.0, 496.0], [147.0, 496.0], [147.0, 515.0], [70.0, 516.0]'
# ...Word 'BILL' has a confidence of 0.994
# ...Word 'TO' has a confidence of 0.998
# Line # 16 has word count '2' and text 'James Starter' within bounding box '[69.0, 543.0], [277.0, 543.0], [277.0, 571.0], [69.0, 570.0]'
# ...Word 'James' has a confidence of 0.994
# ...Word 'Starter' has a confidence of 0.996
# Line # 17 has word count '3' and text '3212 Leghorn Rd' within bounding box '[69.0, 597.0], [264.0, 597.0], [264.0, 623.0], [69.0, 623.0]'
# ...Word '3212' has a confidence of 0.994
# ...Word 'Leghorn' has a confidence of 0.996
# ...Word 'Rd' has a confidence of 0.997
# Line # 18 has word count '2' and text 'Mountain View' within bounding box '[71.0, 638.0], [239.0, 637.0], [239.0, 660.0], [71.0, 661.0]'
# ...Word 'Mountain' has a confidence of 0.995
# ...Word 'View' has a confidence of 0.994
# Line # 19 has word count '1' and text '94040' within bounding box '[69.0, 679.0], [143.0, 679.0], [143.0, 701.0], [69.0, 702.0]'
# ...Word '94040' has a confidence of 0.996
# Line # 20 has word count '1' and text '4087031332' within bounding box '[71.0, 719.0], [214.0, 718.0], [214.0, 742.0], [71.0, 742.0]'
# ...Word '4087031332' has a confidence of 0.991
# Line # 21 has word count '1' and text 'james_starter@email.com' within bounding box '[66.0, 760.0], [364.0, 759.0], [364.0, 785.0], [66.0, 785.0]'
# ...Word 'james_starter@email.com' has a confidence of 0.832
# Line # 22 has word count '1' and text 'DESCRIPTION' within bounding box '[70.0, 866.0], [209.0, 866.0], [210.0, 885.0], [70.0, 886.0]'
# ...Word 'DESCRIPTION' has a confidence of 0.991
# Line # 23 has word count '1' and text 'RATE' within bounding box '[1073.0, 867.0], [1128.0, 866.0], [1128.0, 885.0], [1073.0, 885.0]'
# ...Word 'RATE' has a confidence of 0.994
# Line # 24 has word count '1' and text 'QTY' within bounding box '[1196.0, 867.0], [1242.0, 866.0], [1242.0, 885.0], [1197.0, 887.0]'
# ...Word 'QTY' has a confidence of 0.996
# Line # 25 has word count '1' and text 'AMOUNT' within bounding box '[1319.0, 867.0], [1412.0, 866.0], [1412.0, 885.0], [1319.0, 886.0]'
# ...Word 'AMOUNT' has a confidence of 0.994
# Line # 26 has word count '1' and text 'Burger' within bounding box '[69.0, 931.0], [145.0, 933.0], [145.0, 958.0], [69.0, 957.0]'
# ...Word 'Burger' has a confidence of 0.994
# Line # 27 has word count '1' and text '$6.99' within bounding box '[1061.0, 930.0], [1125.0, 930.0], [1125.0, 953.0], [1062.0, 955.0]'
# ...Word '$6.99' has a confidence of 0.996
# Line # 28 has word count '1' and text '1' within bounding box '[1225.0, 933.0], [1241.0, 935.0], [1240.0, 953.0], [1224.0, 951.0]'
# ...Word '1' has a confidence of 0.996
# Line # 29 has word count '1' and text '$6.99' within bounding box '[1347.0, 931.0], [1412.0, 931.0], [1412.0, 953.0], [1348.0, 955.0]'
# ...Word '$6.99' has a confidence of 0.994
# Line # 30 has word count '1' and text 'Drink' within bounding box '[70.0, 1001.0], [129.0, 1001.0], [128.0, 1024.0], [70.0, 1023.0]'
# ...Word 'Drink' has a confidence of 0.994
# Line # 31 has word count '1' and text '$2.99' within bounding box '[1061.0, 1001.0], [1125.0, 1000.0], [1125.0, 1022.0], [1062.0, 1024.0]'
# ...Word '$2.99' has a confidence of 0.986
# Line # 32 has word count '1' and text '1' within bounding box '[1224.0, 1004.0], [1241.0, 1004.0], [1241.0, 1024.0], [1224.0, 1023.0]'
# ...Word '1' has a confidence of 0.996
# Line # 33 has word count '1' and text '$2.99' within bounding box '[1347.0, 1001.0], [1410.0, 1000.0], [1410.0, 1022.0], [1347.0, 1025.0]'
# ...Word '$2.99' has a confidence of 0.996
# Line # 34 has word count '1' and text 'Icecreame' within bounding box '[70.0, 1073.0], [190.0, 1073.0], [189.0, 1094.0], [70.0, 1093.0]'
# ...Word 'Icecreame' has a confidence of 0.748
# Line # 35 has word count '1' and text '$4.99' within bounding box '[1061.0, 1071.0], [1127.0, 1070.0], [1127.0, 1093.0], [1062.0, 1095.0]'
# ...Word '$4.99' has a confidence of 0.981
# Line # 36 has word count '1' and text '1' within bounding box '[1226.0, 1073.0], [1241.0, 1075.0], [1240.0, 1093.0], [1225.0, 1091.0]'
# ...Word '1' has a confidence of 0.996
# Line # 37 has word count '1' and text '$4.99' within bounding box '[1346.0, 1071.0], [1411.0, 1071.0], [1410.0, 1094.0], [1347.0, 1094.0]'
# ...Word '$4.99' has a confidence of 0.991
# Line # 38 has word count '1' and text 'SUBTOTAL' within bounding box '[740.0, 1144.0], [847.0, 1144.0], [847.0, 1164.0], [740.0, 1164.0]'
# ...Word 'SUBTOTAL' has a confidence of 0.982
# Line # 39 has word count '1' and text '$14.97' within bounding box '[1333.0, 1140.0], [1411.0, 1140.0], [1411.0, 1164.0], [1333.0, 1164.0]'
# ...Word '$14.97' has a confidence of 0.991
# Line # 40 has word count '2' and text 'TAX (9%)' within bounding box '[742.0, 1185.0], [830.0, 1186.0], [830.0, 1208.0], [742.0, 1207.0]'
# ...Word 'TAX' has a confidence of 0.994
# ...Word '(9%)' has a confidence of 0.994
# Line # 41 has word count '1' and text '$1.35' within bounding box '[1347.0, 1181.0], [1413.0, 1181.0], [1413.0, 1203.0], [1348.0, 1204.0]'
# ...Word '$1.35' has a confidence of 0.996
# Line # 42 has word count '1' and text 'TOTAL' within bounding box '[741.0, 1256.0], [808.0, 1255.0], [808.0, 1275.0], [741.0, 1275.0]'
# ...Word 'TOTAL' has a confidence of 0.994
# Line # 43 has word count '1' and text '$16.32' within bounding box '[1332.0, 1251.0], [1411.0, 1251.0], [1412.0, 1274.0], [1332.0, 1274.0]'
# ...Word '$16.32' has a confidence of 0.996
# Line # 44 has word count '1' and text 'BALANCE' within bounding box '[741.0, 1324.0], [839.0, 1323.0], [839.0, 1343.0], [741.0, 1344.0]'
# ...Word 'BALANCE' has a confidence of 0.994
# Line # 45 has word count '2' and text 'USD $16.32' within bounding box '[1239.0, 1333.0], [1413.0, 1333.0], [1413.0, 1363.0], [1239.0, 1363.0]'
# ...Word 'USD' has a confidence of 0.994
# ...Word '$16.32' has a confidence of 0.994
# Line # 46 has word count '1' and text 'DUE' within bounding box '[741.0, 1355.0], [784.0, 1354.0], [784.0, 1373.0], [741.0, 1373.0]'
# ...Word 'DUE' has a confidence of 0.994

# %% [markdown]
# ### Selection Marks

# %%
# --------------------------
# Code Snippet Source 
# https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/ComputerVision/REST/python-disk.md
# --------------------------
if content.selection_marks is not None:
    for selection_mark in content.selection_marks:
        print("Selection mark is '{}' within bounding box '{}' and has a confidence of {}".format(
            selection_mark.state,
            format_bounding_box(selection_mark.bounding_box),
            selection_mark.confidence
        ))
